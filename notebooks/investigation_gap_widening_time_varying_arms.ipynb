# %% [markdown]
# # Research Notebook
#
# ## The goal
#
# The goal here is to understand the impact that data gaps have on the L01 pipeline. As seen, the impact of gaps on the telemetry variables result in a widening of the data gaps in the overall Michelson-like variables. I want to try and understand
#
# * What type of data gap is most impacted
# * What generation of TDI is most impactful
# * What do the data gap widening depend on?
# * Can I build a distribution of data gaps?

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import sys
import matplotlib.pyplot as plt
from tqdm import tqdm as tqdm
data_direc = "../data_for_simulations"
sys.path.append("../../artifacts_gen/gaps/")  # if gap_widening_utils.py is in the parent directory
from lisa_gap import GapMaskGenerator

sys.path.append("../utility_funcs")  # if gap_widening_utils.py is in the parent directory
from gap_widening_utils import (
    construct_mask_single_gap,
    gap_augmentation_expression,
    widening_gap_X1,
    widening_gap_X2
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Set up the instrument simulator

# %%
820_000_0*0.25/60/60/24
# Out:
# 23.72685185185185

# %%
# Set up lolipops pipeline
from pathlib import Path
from lisainstrument import Instrument
import logging

# simlen = 120_000
simlen = 8200000

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logging.getLogger('lisainstrument').setLevel(logging.INFO)
instr_time_varying = Instrument(size=simlen, dt = 0.25, orbits = 'orbits_non_equal.h5', seed=1234)

instr_time_varying.disable_all_noises(excluding=['laser', 'test-mass', 'oms']) 
instr_time_varying.simulate()

instr_time_varying.write('static_short_simulation.h5', mode='w')
# Out:
# 2025-07-17 13:45:29,031 - INFO - Initializing instrumental simulation
# 2025-07-17 13:45:29,051 - INFO - Computing measurement time vector (size=8200000, dt=0.25)
# 2025-07-17 13:45:29,059 - INFO - Computing physics time vector (size=32800000, dt=0.0625)
# 2025-07-17 13:45:29,114 - INFO - Computing telemetry time vector (size=25, dt=86400.0)
# 2025-07-17 13:45:29,176 - INFO - Using orbit file 'orbits_non_equal.h5'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 11
#       9 logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
#      10 logging.getLogger('lisainstrument').setLevel(logging.INFO)
# ---> 11 instr_time_varying = Instrument(size=simlen, dt = 0.25, orbits = 'orbits_non_equal.h5', seed=1234)
#      13 instr_time_varying.disable_all_noises(excluding=['laser', 'test-mass', 'oms'])
#      14 instr_time_varying.simulate()
#
# File /opt/miniconda3/envs/pytdi_env/lib/python3.12/site-packages/lisainstrument/instrument.py:382, in Instrument.__init__(self, size, dt, t0, seed, physics_upsampling, aafilter, telemetry_downsampling, initial_telemetry_size, orbits, orbit_dataset, gws, interpolation, glitches, lock, fplan, laser_asds, laser_shape, central_freq, offset_freqs, modulation_asds, modulation_freqs, tdir_modulations, clock_asds, clock_offsets, clock_freqoffsets, clock_freqlindrifts, clock_freqquaddrifts, clockinv_tolerance, clockinv_maxiter, backlink_asds, backlink_fknees, testmass_asds, testmass_fknees, testmass_fbreak, testmass_shape, testmass_frelax, oms_asds, oms_fknees, moc_time_correlation_asds, mosa_longitudinal_jitter_asds, sc_angular_jitter_asds, sc_angular_jitter_fknees, mosa_angular_jitter_asds, mosa_angular_jitter_fknees, mosa_angles, ttl_coeffs, dws_asds, ranging_biases, ranging_asds, prn_ambiguity, electro_delays, concurrent)
#     377 self.telemetry_physics_slice = slice(
#     378     first_sample, first_sample + self.physics_size
#     379 )
#     381 # Orbits, gravitational waves, glitches
# --> 382 self.init_orbits(orbits, orbit_dataset)
#     383 self.init_gws(gws)
#     384 self.init_glitches(glitches)
#
# File /opt/miniconda3/envs/pytdi_env/lib/python3.12/site-packages/lisainstrument/instrument.py:893, in Instrument.init_orbits(self, orbits, orbit_dataset)
#     891     self.init_orbits_file_1_0(orbitf)
#     892 elif version in SpecifierSet("== 2.*", True):
# --> 893     self.init_orbits_file_2_0(orbitf)
#     894 else:
#     895     raise ValueError(f"unsupported orbit file version '{version}'")
#
# File /opt/miniconda3/envs/pytdi_env/lib/python3.12/site-packages/lisainstrument/instrument.py:995, in Instrument.init_orbits_file_2_0(self, orbitf)
#     985 ppr_dataset = (
#     986     orbitf["tcb/ltt"]
#     987     if self.orbit_dataset == "tcb/ltt"
#     988     else orbitf["tps/ppr"]
#     989 )
#     990 d_ppr_dataset = (
#     991     orbitf["tcb/d_ltt"]
#     992     if self.orbit_dataset == "tcb/ltt"
#     993     else orbitf["tps/d_ppr"]
#     994 )
# --> 995 self.pprs = ForEachMOSA(
#     996     lambda mosa: ppr_dataset[0, link_index[mosa]]
#     997     + int_interpolate(d_ppr_dataset[:, link_index[mosa]], self.physics_t)
#     998     - int_interpolate(d_ppr_dataset[:, link_index[mosa]], self.orbit_t0)
#     999 )
#    1000 logger.debug("Interpolating proper pseudo-range derivatives")
#    1001 self.d_pprs = ForEachMOSA(
#    1002     lambda mosa: interpolate(
#    1003         d_ppr_dataset[:, link_index[mosa]], self.physics_t
#    1004     )
#    1005 )
#
# File /opt/miniconda3/envs/pytdi_env/lib/python3.12/site-packages/lisainstrument/containers.py:52, in ForEachObject.__init__(self, values, concurrent)
#      50             self.dict = dict(zip(indices, computed_values))
#      51     else:
# ---> 52         self.dict = {mosa: values(mosa) for mosa in self.indices()}
#      53 elif isinstance(values, h5py.Dataset):
#      54     self.dict = {mosa: values[mosa] for mosa in self.indices()}
#
# File /opt/miniconda3/envs/pytdi_env/lib/python3.12/site-packages/lisainstrument/instrument.py:997, in Instrument.init_orbits_file_2_0.<locals>.<lambda>(mosa)
#     985 ppr_dataset = (
#     986     orbitf["tcb/ltt"]
#     987     if self.orbit_dataset == "tcb/ltt"
#     988     else orbitf["tps/ppr"]
#     989 )
#     990 d_ppr_dataset = (
#     991     orbitf["tcb/d_ltt"]
#     992     if self.orbit_dataset == "tcb/ltt"
#     993     else orbitf["tps/d_ppr"]
#     994 )
#     995 self.pprs = ForEachMOSA(
#     996     lambda mosa: ppr_dataset[0, link_index[mosa]]
# --> 997     + int_interpolate(d_ppr_dataset[:, link_index[mosa]], self.physics_t)
#     998     - int_interpolate(d_ppr_dataset[:, link_index[mosa]], self.orbit_t0)
#     999 )
#    1000 logger.debug("Interpolating proper pseudo-range derivatives")
#    1001 self.d_pprs = ForEachMOSA(
#    1002     lambda mosa: interpolate(
#    1003         d_ppr_dataset[:, link_index[mosa]], self.physics_t
#    1004     )
#    1005 )
#
# File /opt/miniconda3/envs/pytdi_env/lib/python3.12/site-packages/lisainstrument/instrument.py:973, in Instrument.init_orbits_file_2_0.<locals>.<lambda>(data, t)
#     967 times = (
#     968     orbitf.attrs["t0"] + np.arange(orbitf.attrs["size"]) * orbitf.attrs["dt"]
#     969 )
#     970 interpolate = lambda data, t: InterpolatedUnivariateSpline(
#     971     times, data, k=5, ext="raise"
#     972 )(t)
# --> 973 int_interpolate = lambda data, t: InterpolatedUnivariateSpline(
#     974     times, data, k=5, ext="raise"
#     975 ).antiderivative()(t)
#     976 link_index = {"12": 0, "23": 1, "31": 2, "13": 3, "32": 4, "21": 5}
#     977 sc_index = {"1": 0, "2": 1, "3": 2}
#
# File /opt/miniconda3/envs/pytdi_env/lib/python3.12/site-packages/scipy/interpolate/_fitpack2.py:406, in UnivariateSpline.__call__(self, x, nu, ext)
#     404         raise ValueError(f"Unknown extrapolation mode {ext}.") from e
#     405 with FITPACK_LOCK:
# --> 406     return _fitpack_impl.splev(x, self._eval_args, der=nu, ext=ext)
#
# File /opt/miniconda3/envs/pytdi_env/lib/python3.12/site-packages/scipy/interpolate/_fitpack_impl.py:326, in splev(x, tck, der, ext)
#     324 x = atleast_1d(x).ravel()
#     325 if der == 0:
# --> 326     y, ier = dfitpack.splev(t, c, k, x, ext)
#     327 else:
#     328     y, ier = dfitpack.splder(t, c, k, x, der, ext)
#
# KeyboardInterrupt:

# %%
from pytdi import Data

from pytdi.michelson import compute_factorized_michelson

data = Data.from_instrument(instr_time_varying)
# Out:
# 2025-07-17 13:33:54,781 - INFO - Loading instrument object '<lisainstrument.instrument.Instrument object at 0x1474e64e0>'
# 2025-07-17 13:33:54,782 - WARNING - You are using LISA Instrument in a version that might not be fully supported
# 2025-07-17 13:33:54,782 - INFO - Initializing data object
# 2025-07-17 13:33:54,783 - INFO - Computing delay derivatives

# %% [markdown]
# # Widening of the gap due to delays
# ## The $\eta$ variables
#
# Now in the next cell we are going to verify our formula for the widening of the eta variables

# %%
measurement_values = data.MEASUREMENTS
ifos = data.measurements

mprs = data.delays
mpr_derivatives = data.delay_derivatives
MOSAS = data.MOSAS
dt = 1/data.fs

# %%
# I want to trim the mprs values by 1000 points at the start and end
N = 1000
mprs_trimmed = {}
for item in list(mprs.keys()):
    mprs_trimmed[item] = mprs[item][1000:-1000]

# %%
mprs_trimmed
# Out:
# {'d_12': array([8.33242373, 8.33242373, 8.33242373, ..., 8.33884103, 8.33884103,
#         8.33884103], shape=(8198000,)),
#  'd_23': array([8.30282196, 8.30282196, 8.30282196, ..., 8.30522902, 8.30522902,
#         8.30522902], shape=(8198000,)),
#  'd_31': array([8.33242219, 8.33242219, 8.33242219, ..., 8.3260788 , 8.32607879,
#         8.32607879], shape=(8198000,)),
#  'd_13': array([8.33159326, 8.33159326, 8.33159326, ..., 8.32524982, 8.32524982,
#         8.32524982], shape=(8198000,)),
#  'd_32': array([8.30446786, 8.30446786, 8.30446786, ..., 8.30687493, 8.30687493,
#         8.30687493], shape=(8198000,)),
#  'd_21': array([8.3315948 , 8.3315948 , 8.3315948 , ..., 8.33801214, 8.33801214,
#         8.33801214], shape=(8198000,))}

# %%
def nanify_telemetry_variables(data, masking_function):
    """
    Apply a masking function (with NaNs) to telemetry variables, pseudo-ranges, and their derivatives.

    Args:
        data (object): Telemetry object with .ifos attribute (dict-like).
        masking_function (np.ndarray): Array of 1s and NaNs to apply as a mask.

    Returns:
        tuple: (telemetry_w_gaps, mprs_w_nans, mpr_derivatives_w_nans)
            telemetry_w_gaps: telemetry object with masked .ifos fields
            mprs_w_nans: dict of masked pseudo-ranges
            mpr_derivatives_w_nans: dict of masked pseudo-range derivatives
        telemetry (object): Telemetry object with .ifos attribute (dict-like).
        mprs (dict): Dictionary of pseudo-range arrays, keyed by MOSA.
        mpr_derivatives (dict): Dictionary of pseudo-range derivative arrays, keyed by MOSA.
        masking_function (np.ndarray): Array of 1s and NaNs to apply as a mask.

    Returns:
        tuple: (telemetry_w_gaps, mprs_w_nans, mpr_derivatives_w_nans)
            telemetry_w_gaps: telemetry object with masked .ifos fields
            mprs_w_nans: dict of masked pseudo-ranges
            mpr_derivatives_w_nans: dict of masked pseudo-range derivatives
    """
    import copy

    # Deep copy to avoid modifying original data
    MOSAS = data.MOSAS
    data_w_gaps = copy.deepcopy(data)

    # Build label lists for all relevant telemetry fields
    tmi_label = [f"tmi_{mosa}" for mosa in MOSAS]
    rfi_label = [f"rfi_{mosa}" for mosa in MOSAS]
    rfi_sb_label = [f"rfi_sb_{mosa}" for mosa in MOSAS]
    isi_label = [f"isi_{mosa}" for mosa in MOSAS]
    isi_sb_label = [f"isi_sb_{mosa}" for mosa in MOSAS]

    # Apply mask to all telemetry fields
    for tmi_item, rfi_item, rfi_sb_item, isi_item, isi_sb_item in zip(
        tmi_label, rfi_label, rfi_sb_label, isi_label, isi_sb_label
    ):
        data_w_gaps.measurements[tmi_item] = data.measurements[tmi_item] * masking_function
        data_w_gaps.measurements[rfi_item] = data.measurements[rfi_item] * masking_function
        data_w_gaps.measurements[rfi_sb_item] = data.measurements[rfi_sb_item] * masking_function
        data_w_gaps.measurements[isi_item] = data.measurements[isi_item] * masking_function
        data_w_gaps.measurements[isi_sb_item] = data.measurements[isi_sb_item] * masking_function

    # Deep copy and mask pseudo-ranges and their derivatives
    for delay_craft in list(data.delays.keys()):
        data_w_gaps.delays[delay_craft] = masking_function * data.delays[delay_craft]
        data_w_gaps.delay_derivatives[delay_craft] = masking_function * data.delay_derivatives[delay_craft]

    return data_w_gaps

# %%
# Construct gap class

CONTROL_NANS = True
GAP_CLASS = False

sim_t = np.arange(0, simlen * dt, dt)


N_tel_nans= 20

masking_function = construct_mask_single_gap(N_tel_nans, length = simlen)


plt.plot(sim_t / 60 / 60 / 24, masking_function)
plt.title("Full gap mask")
plt.xlabel("Time [day]")
plt.ylabel("Gap mask")
plt.grid(True)

print(
    "Lost out on approximately",
    np.sum(np.isnan(masking_function)) * 0.25 / 60 / 60,
    "hours of data",
)
print(
    "This ammounts to {} number of samples".format(np.sum(np.isnan(masking_function)))
)
# Out:
# Lost out on approximately 0.0013888888888888887 hours of data
# This ammounts to 20 number of samples

# %%
from pytdi.intervar import compute_etas

N_nans = 2000
order = 27
masking_function = construct_mask_single_gap(N_nans, length = simlen)
data_w_gaps = nanify_telemetry_variables(data, masking_function)
etas_w_gaps_nans = compute_etas(data_w_gaps, order, unit = "frequency")

N_nans_in_data = np.sum(np.isnan(data_w_gaps.measurements["tmi_12"]))
print("Number of nans in data", N_nans_in_data)
N_nans_in_eta_pytdi = np.sum(np.isnan(etas_w_gaps_nans["eta_12"]))
widening_gap_eta_pytdi = N_nans_in_eta_pytdi - N_nans
print("Number of nans in the eta variables = ", N_nans_in_eta_pytdi)
print("Overall widening of gap in eta variables = ", widening_gap_eta_pytdi)
# Out:
# 2025-07-17 13:38:43,648 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318b9e0>'
# 2025-07-17 13:38:43,659 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318b9e0>'
# /opt/miniconda3/envs/pytdi_env/lib/python3.12/site-packages/pytdi/dsp.py:113: RuntimeWarning: invalid value encountered in cast
#   shift_ints = shift_ints.astype(int)
# 2025-07-17 13:38:49,076 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bb60>'
# 2025-07-17 13:38:49,085 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bb60>'
# 2025-07-17 13:38:53,907 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bce0>'
# 2025-07-17 13:38:53,917 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bce0>'
# 2025-07-17 13:38:58,670 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318be60>'
# 2025-07-17 13:38:58,678 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318be60>'
# 2025-07-17 13:39:02,010 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bdd0>'
# 2025-07-17 13:39:02,019 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bdd0>'
# 2025-07-17 13:39:05,202 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1433f8170>'
# 2025-07-17 13:39:05,211 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1433f8170>'
# Number of nans in data 2000
# Number of nans in the eta variables =  2047
# Overall widening of gap in eta variables =  47

# %%
# Check formula
constant_delay = data_w_gaps.delays['d_12'][1000:][0]
delay = constant_delay/dt # Here we take the mean LTT. 

widening_gap_eta_theory, N_nans_in_eta_theory = gap_augmentation_expression(order, N_nans, delay, delay_number=1.0)
print("Number of nans in the eta variables = ", N_nans_in_eta_theory)
print("Overall widening of gap in eta variables = ", widening_gap_eta_theory)
# Out:
# Number of nans in the eta variables =  2047
# Overall widening of gap in eta variables =  47

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 10))

idx_start_gap = np.argwhere(np.isnan(masking_function) == True)[0][0]
idx_end_gap = np.argwhere(np.isnan(masking_function) == True)[-1][-1]
# First subplot: Original plot with gaps and no gaps
j = 1000
axs[0].plot(sim_t, data_w_gaps.measurements["tmi_23"], label="with gaps", alpha=1)
axs[0].plot(sim_t, data.measurements["tmi_23"], label="no gaps", alpha=0.2)
axs[0].set_xlim([sim_t[idx_start_gap] - j, sim_t[idx_start_gap] + j])
axs[0].set_ylabel(r"TMI_23")
# axs[0].set_ylim([-4100, -3200])
axs[0].set_xlabel("Time [s]")
axs[0].legend()
axs[0].set_title("TMI_23 with and without gaps")

# Second subplot: Absolute difference between the two
absolute_difference = np.abs(data_w_gaps.measurements["tmi_23"] - data.measurements["tmi_23"])
axs[1].plot(sim_t, absolute_difference, label="Absolute Difference", color="red")
axs[1].set_xlim([sim_t[idx_start_gap] - j, sim_t[idx_start_gap] + j])
axs[1].set_ylabel("Absolute Difference")
axs[1].set_xlabel("Time [s]")
axs[1].legend()
axs[1].set_title("Absolute Difference between TMI_23 with and without gaps")

plt.tight_layout()
plt.show()

# %%
order = 45
results_testing_N_nans = []
N_nans_in_telem_values = np.logspace(0, 2, num=50, dtype=int)  # Logarithmic spacing from 1 to 10000

for N_nans in tqdm(N_nans_in_telem_values):
    # Construct masking function
    masking_function = construct_mask_single_gap(N_nans, length=simlen)
        
    # Generate telemetry with gaps
    data_w_gaps = nanify_telemetry_variables(data, masking_function)

    # Compute eta variables with gaps
    etas_w_gaps_nans = compute_etas(data_w_gaps, order, unit="frequency")        
    # Calculate N_nans and widening for pytdi
    N_nans_in_eta_pytdi = np.sum(np.isnan(etas_w_gaps_nans["eta_12"]))
    widening_gap_eta_pytdi = N_nans_in_eta_pytdi - N_nans

    # Calculate N_nans and widening for theoretical model
    widening_gap_eta_theory, N_nans_in_eta_theory = gap_augmentation_expression(
        order, N_nans, delay, delay_number=1
    )
        
    # Append results to the list
    results_testing_N_nans.append({
        "N_nans": N_nans,
        "N_nans_in_eta_pytdi": N_nans_in_eta_pytdi,
        "N_nans_in_eta_theory": N_nans_in_eta_theory,
        "widening_gap_eta_pytdi": widening_gap_eta_pytdi,
        "widening_gap_eta_theory": widening_gap_eta_theory
    })
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# 2025-07-17 13:40:10,846 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318b9e0>'
# 2025-07-17 13:40:10,854 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318b9e0>'
# 2025-07-17 13:40:22,026 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bb60>'
# 2025-07-17 13:40:22,038 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bb60>'
# 2025-07-17 13:40:31,738 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bce0>'
# 2025-07-17 13:40:31,751 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bce0>'
# 2025-07-17 13:40:42,846 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318be60>'
# 2025-07-17 13:40:42,857 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318be60>'
# 2025-07-17 13:40:49,906 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bdd0>'
# 2025-07-17 13:40:49,917 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bdd0>'
# 2025-07-17 13:40:56,594 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1433f8170>'
# 2025-07-17 13:40:56,603 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1433f8170>'
#   2%|▏         | 1/50 [00:53<43:47, 53.63s/it]2025-07-17 13:41:04,354 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318b9e0>'
# 2025-07-17 13:41:04,363 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318b9e0>'
# 2025-07-17 13:41:14,902 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bb60>'
# 2025-07-17 13:41:14,915 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bb60>'
# 2025-07-17 13:41:24,805 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bce0>'
# 2025-07-17 13:41:24,820 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bce0>'
# 2025-07-17 13:41:34,772 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318be60>'
# 2025-07-17 13:41:34,788 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318be60>'
# 2025-07-17 13:41:41,370 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bdd0>'
# 2025-07-17 13:41:41,384 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bdd0>'
# 2025-07-17 13:41:47,889 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1433f8170>'
# 2025-07-17 13:41:47,903 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1433f8170>'
#   4%|▍         | 2/50 [01:44<41:34, 51.96s/it]2025-07-17 13:41:55,057 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318b9e0>'
# 2025-07-17 13:41:55,067 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318b9e0>'
# 2025-07-17 13:42:04,948 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bb60>'
# 2025-07-17 13:42:04,957 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bb60>'
# 2025-07-17 13:42:15,687 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bce0>'
# 2025-07-17 13:42:15,697 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bce0>'
# 2025-07-17 13:42:26,437 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318be60>'
# 2025-07-17 13:42:26,448 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318be60>'
# 2025-07-17 13:42:33,187 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bdd0>'
# 2025-07-17 13:42:33,197 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bdd0>'
# 2025-07-17 13:42:39,752 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1433f8170>'
# 2025-07-17 13:42:39,760 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1433f8170>'
#   6%|▌         | 3/50 [02:36<40:39, 51.91s/it]2025-07-17 13:42:46,959 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318b9e0>'
# 2025-07-17 13:42:46,968 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318b9e0>'
# 2025-07-17 13:42:57,095 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bb60>'
# 2025-07-17 13:42:57,104 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bb60>'
# 2025-07-17 13:43:07,062 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bce0>'
# 2025-07-17 13:43:07,071 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bce0>'
# 2025-07-17 13:43:17,114 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318be60>'
# 2025-07-17 13:43:17,125 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318be60>'
# 2025-07-17 13:43:23,836 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bdd0>'
# 2025-07-17 13:43:23,845 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bdd0>'
# 2025-07-17 13:43:30,404 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1433f8170>'
# 2025-07-17 13:43:30,415 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1433f8170>'
#   8%|▊         | 4/50 [03:26<39:26, 51.44s/it]2025-07-17 13:43:37,621 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318b9e0>'
# 2025-07-17 13:43:37,630 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318b9e0>'
# 2025-07-17 13:43:47,421 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bb60>'
# 2025-07-17 13:43:47,431 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bb60>'
# 2025-07-17 13:43:57,382 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bce0>'
# 2025-07-17 13:43:57,391 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bce0>'
# 2025-07-17 13:44:07,050 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318be60>'
# 2025-07-17 13:44:07,059 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318be60>'
# 2025-07-17 13:44:13,441 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bdd0>'
# 2025-07-17 13:44:13,449 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bdd0>'
# 2025-07-17 13:44:19,811 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1433f8170>'
# 2025-07-17 13:44:19,820 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1433f8170>'
#  10%|█         | 5/50 [04:16<37:55, 50.57s/it]2025-07-17 13:44:26,658 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318b9e0>'
# 2025-07-17 13:44:26,667 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318b9e0>'
# 2025-07-17 13:44:36,312 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bb60>'
# 2025-07-17 13:44:36,321 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bb60>'
# 2025-07-17 13:44:46,508 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bce0>'
# 2025-07-17 13:44:46,517 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bce0>'
# 2025-07-17 13:44:56,257 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318be60>'
# 2025-07-17 13:44:56,267 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318be60>'
# 2025-07-17 13:45:02,815 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bdd0>'
# 2025-07-17 13:45:02,824 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bdd0>'
# 2025-07-17 13:45:09,633 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1433f8170>'
# 2025-07-17 13:45:09,645 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1433f8170>'
#  12%|█▏        | 6/50 [05:06<36:59, 50.43s/it]2025-07-17 13:45:16,819 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318b9e0>'
# 2025-07-17 13:45:16,829 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318b9e0>'
# 2025-07-17 13:45:27,254 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14318bb60>'
# 2025-07-17 13:45:27,263 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14318bb60>'
#  12%|█▏        | 6/50 [05:18<38:52, 53.01s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 13
#      10 data_w_gaps = nanify_telemetry_variables(data, masking_function)
#      12 # Compute eta variables with gaps
# ---> 13 etas_w_gaps_nans = compute_etas(data_w_gaps, order, unit="frequency")
#      14 # Calculate N_nans and widening for pytdi
#      15 N_nans_in_eta_pytdi = np.sum(np.isnan(etas_w_gaps_nans["eta_12"]))
#
# File /opt/miniconda3/envs/pytdi_env/lib/python3.12/site-packages/pytdi/intervar.py:163, in compute_etas(data, order, unit)
#     150 def compute_etas(data, order=45, unit='frequency'):
#     151     r"""Evaluate intermediary variables :math:`\eta_{ij}`.
#     152
#     153     This can be used as an alternative to concatenation, to evaluate numerically
#    (...)    160         unit (str): unit of input data, either 'frequency' or 'phase'
#     161     """
#     162     return {
# --> 163         key: eta.build(**data.args)(data.measurements, order=order, unit=unit)
#     164         for key, eta in ETA_SET.items()
#     165     }
#
# File /opt/miniconda3/envs/pytdi_env/lib/python3.12/site-packages/pytdi/core.py:298, in TDICombination.build.<locals>.call(measurements, order, unit)
#     295 for factor, operator in polynomial:
#     296     # Shift the data, and add it to the result
#     297     shift = shifts[tuple(operator)]
# --> 298     shifted = dsp.timeshift(measurements[measurement], shift * fs, order)
#     299     if unit == 'phase':
#     300         result += factor * shifted
#
# File /opt/miniconda3/envs/pytdi_env/lib/python3.12/site-packages/pytdi/dsp.py:112, in timeshift(data, shifts, order)
#     110 shift_ints = np.floor(shifts)
#     111 shift_fracs = shifts - shift_ints
# --> 112 taps = lagrange_taps(shift_fracs, halfp)
#     113 shift_ints = shift_ints.astype(int)
#     115 # Handle constant shifts
#
# File /opt/miniconda3/envs/pytdi_env/lib/python3.12/site-packages/pytdi/dsp.py:173, in lagrange_taps(shift_fracs, halfp)
#     170     taps[halfp] = shift_fracs
#     172     for j in range(2, halfp):
# --> 173         taps *= 1 - (shift_fracs / j)**2
#     175     taps *= (1 + shift_fracs) * (1 - shift_fracs / halfp)
#     176 else:
#
# KeyboardInterrupt:

# %%
# Plot the results of the above cell

import matplotlib.pyplot as plt
import numpy as np

# Extract data from results
N_nans_in_telem_values = [result["N_nans"] for result in results_testing_N_nans]
widening_gap_eta_pytdi = [result["widening_gap_eta_pytdi"] for result in results_testing_N_nans]
widening_gap_eta_theory = [result["widening_gap_eta_theory"] for result in results_testing_N_nans]

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(N_nans_in_telem_values, widening_gap_eta_pytdi, label="pytdi", marker="o", linestyle="-", color="blue")
plt.plot(N_nans_in_telem_values, widening_gap_eta_theory, label="Prediction", marker="s", linestyle="--", color="orange", alpha = 0.7)

# Add labels, legend, and grid
plt.xscale("log")
plt.xlabel("Number of NaNs in telemetry", fontsize=20)
plt.ylabel(r"Widening of Gap in $\eta$ variables", fontsize=20)
plt.title("Comparison of Gap Widening: pytdi vs Prediction", fontsize=20)
plt.legend(fontsize=26)

# Increase tick sizes
plt.tick_params(axis="both", which="major", labelsize=16)

plt.grid(True, which="both", linestyle="--", linewidth=0.5)

# Save and show the plot
plt.tight_layout()
# plt.savefig("../Plots/gap_widening_comparison.png", dpi=300)  # Save as a high-resolution image
plt.show()

# %% [markdown]
# # What do we learn here?
# ## For large strings of missing data, gap augmentation is constant.

# %%
results_by_order = {}

# Define the gap configurations and range of orders
gap_configurations = [1, 10, 100]
orders = range(25, 81,2)  # From 25 to 81 inclusive

# Loop over each gap configuration
for N_nans in gap_configurations:
    results_by_order[N_nans] = []  # Initialize results for this gap configuration
    
    # Construct masking function
    masking_function = construct_mask_single_gap(N_nans, length=simlen) 
    # Generate telemetry with gaps
    data_w_gaps = nanify_telemetry_variables(data, masking_function)
    for order in tqdm(orders):
        
        # Compute eta variables with gaps
        etas_w_gaps_nans = compute_etas(data_w_gaps, order, unit="frequency")        
        # Calculate N_nans and widening for pytdi
        N_nans_in_eta_pytdi = np.sum(np.isnan(etas_w_gaps_nans["eta_12"]))
        widening_gap_eta_pytdi = N_nans_in_eta_pytdi - N_nans

        # Calculate N_nans and widening for theoretical model
        widening_gap_eta_theory, N_nans_in_eta_theory = gap_augmentation_expression(
            order, N_nans, delay, delay_number=1
        )
        
        # Append results to the list for this gap configuration
        results_by_order[N_nans].append({
            "order": order,
            "N_nans_in_eta_pytdi": N_nans_in_eta_pytdi,
            "N_nans_in_eta_theory": N_nans_in_eta_theory,
            "widening_gap_eta_pytdi": widening_gap_eta_pytdi,
            "widening_gap_eta_theory": widening_gap_eta_theory
        })
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]2025-07-16 11:32:48,582 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:48,582 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:48,640 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:48,641 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:48,689 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:48,690 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:48,737 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:48,737 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:48,767 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:48,768 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:48,798 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:32:48,798 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#   4%|▎         | 1/28 [00:00<00:06,  4.01it/s]2025-07-16 11:32:48,831 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:48,832 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:48,886 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:48,886 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:48,939 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:48,939 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:48,993 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:48,994 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:49,029 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:49,029 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:49,063 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:32:49,063 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#   7%|▋         | 2/28 [00:00<00:06,  3.84it/s]2025-07-16 11:32:49,099 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:49,099 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:49,159 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:49,159 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:49,224 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:49,224 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:49,283 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:49,283 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:49,321 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:49,321 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:49,361 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:32:49,362 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#  11%|█         | 3/28 [00:00<00:07,  3.55it/s]2025-07-16 11:32:49,406 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:49,406 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:49,476 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:49,476 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:49,544 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:49,544 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:49,612 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:49,613 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:49,657 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:49,658 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:49,699 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:32:49,699 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#  14%|█▍        | 4/28 [00:01<00:07,  3.27it/s]2025-07-16 11:32:49,750 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:49,750 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:49,833 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:49,834 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:49,918 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:49,918 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:49,998 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:49,999 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:50,062 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:50,063 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:50,121 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:32:50,121 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#  18%|█▊        | 5/28 [00:01<00:08,  2.87it/s]2025-07-16 11:32:50,172 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:50,173 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:50,254 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:50,254 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:50,331 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:50,332 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:50,415 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:50,416 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:50,477 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:50,477 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:50,535 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:32:50,536 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#  21%|██▏       | 6/28 [00:02<00:08,  2.68it/s]2025-07-16 11:32:50,595 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:50,596 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:50,689 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:50,690 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:50,782 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:50,783 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:50,877 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:50,878 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:50,940 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:50,940 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:50,998 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:32:50,999 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#  25%|██▌       | 7/28 [00:02<00:08,  2.48it/s]2025-07-16 11:32:51,058 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:51,058 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:51,155 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:51,155 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:51,252 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:51,253 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:51,347 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:51,347 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:51,408 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:51,408 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:51,473 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:32:51,473 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#  29%|██▊       | 8/28 [00:02<00:08,  2.34it/s]2025-07-16 11:32:51,540 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:51,541 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:51,644 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:51,645 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:51,740 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:51,741 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:51,844 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:51,845 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:51,922 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:51,923 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:51,988 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:32:51,989 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#  32%|███▏      | 9/28 [00:03<00:08,  2.18it/s]2025-07-16 11:32:52,066 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:52,066 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:52,174 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:52,174 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:52,293 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:52,294 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:52,410 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:52,410 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:52,484 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:52,485 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:52,558 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:32:52,558 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#  36%|███▌      | 10/28 [00:04<00:08,  2.03it/s]2025-07-16 11:32:52,636 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:52,636 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:32:52,759 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:52,760 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:32:52,871 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:52,871 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:32:52,994 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:52,995 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:32:53,079 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:53,079 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:32:53,167 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:32:53,168 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#
- INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:33:44,048 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:33:44,245 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:33:44,245 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:33:44,441 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:33:44,442 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:33:44,577 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:33:44,577 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:33:44,718 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:33:44,719 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#  71%|███████▏  | 20/28 [00:11<00:07,  1.11it/s]2025-07-16 11:33:44,848 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:33:44,848 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:33:45,060 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:33:45,060 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:33:45,270 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:33:45,270 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:33:45,480 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:33:45,480 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:33:45,625 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:33:45,625 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:33:45,770 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:33:45,770 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#  75%|███████▌  | 21/28 [00:12<00:06,  1.06it/s]2025-07-16 11:33:45,907 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:33:45,907 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:33:46,141 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:33:46,142 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:33:46,369 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:33:46,369 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:33:46,595 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:33:46,596 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:33:46,756 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:33:46,757 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:33:46,921 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:33:46,922 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#  79%|███████▊  | 22/28 [00:14<00:06,  1.01s/it]2025-07-16 11:33:47,075 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:33:47,076 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:33:47,313 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:33:47,314 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:33:47,569 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:33:47,570 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:33:47,819 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:33:47,820 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:33:47,978 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:33:47,979 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:33:48,138 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:33:48,138 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#  82%|████████▏ | 23/28 [00:15<00:05,  1.08s/it]2025-07-16 11:33:48,295 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:33:48,295 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:33:48,542 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:33:48,543 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:33:48,785 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:33:48,785 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:33:49,026 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:33:49,026 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:33:49,203 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:33:49,204 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:33:49,371 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:33:49,371 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#  86%|████████▌ | 24/28 [00:16<00:04,  1.12s/it]2025-07-16 11:33:49,530 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:33:49,530 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:33:49,773 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:33:49,773 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:33:50,016 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:33:50,016 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:33:50,268 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:33:50,268 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:33:50,435 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:33:50,436 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:33:50,606 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:33:50,607 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#  89%|████████▉ | 25/28 [00:17<00:03,  1.16s/it]2025-07-16 11:33:50,781 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:33:50,782 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:33:51,038 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:33:51,038 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:33:51,298 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:33:51,299 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:33:51,564 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:33:51,564 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:33:51,745 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:33:51,745 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:33:51,937 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:33:51,937 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#  93%|█████████▎| 26/28 [00:19<00:02,  1.22s/it]2025-07-16 11:33:52,134 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:33:52,135 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:33:52,435 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:33:52,436 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:33:52,718 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:33:52,718 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:33:52,991 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:33:52,991 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:33:53,171 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:33:53,171 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:33:53,359 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:33:53,360 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
#  96%|█████████▋| 27/28 [00:20<00:01,  1.28s/it]2025-07-16 11:33:53,545 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:33:53,546 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:33:53,830 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:33:53,831 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:33:54,149 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:33:54,149 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:33:54,440 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:33:54,441 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:33:54,630 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:33:54,630 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:33:54,822 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:33:54,823 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 100%|██████████| 28/28 [00:22<00:00,  1.27it/s]

# %%
import matplotlib.pyplot as plt
plt.clf()
# Create a single plot for all gap configurations
plt.figure(figsize=(12, 8))

# Define markers and colors for each gap configuration
markers = ["o", "s", "D"]
colors = ["blue", "orange", "green"]

# Loop through each gap configuration and plot the results
for idx, (N_nans, results) in enumerate(results_by_order.items()):
    # Extract data for this N_nans configuration
    orders = [result["order"] for result in results]
    widening_gap_eta_pytdi = [result["widening_gap_eta_pytdi"] for result in results]
    widening_gap_eta_theory = [result["widening_gap_eta_theory"] for result in results]

    # Plot pytdi results (solid lines)
    plt.plot(
        orders, widening_gap_eta_pytdi,
        label=f"PyTDI (N_nans={N_nans})", 
        linestyle="-", color=colors[idx], zorder=1
    )
    
    # Plot theoretical results (dashed lines)
    plt.plot(
        orders, widening_gap_eta_theory, 
        label=f"Prediction (N_nans={N_nans})", 
        marker=markers[idx], color=colors[idx], zorder=2
    )

# Add labels, legend, and grid
plt.xlabel("Order of Interpolant", fontsize=20)
plt.ylabel(r"Widening of Gap in $\eta$ Variables", fontsize=20)
plt.title("Comparison of Gap Widening: Lolipops vs Theory", fontsize=20)
plt.legend(fontsize=12, loc="upper left")
plt.grid(True, linestyle="--", linewidth=0.5)

# Increase tick sizes
plt.tick_params(axis="both", which="major", labelsize=16)

# Save and show the plot
plt.tight_layout()
# plt.savefig("../Plots/gap_widening_comparison_all_configs.png", dpi=300)  # Save as a high-resolution image
plt.show()

# %% [markdown]
# # Now let's try to do the same thing but with factorized variables
#
# We have no shown that the widening of the gap in the $\eta$ variables is sensitive to three things:
#
# * The number of consecutive missing data in the telemetry variables
# * The integer delay used when computing the interpolation
# * The order of the interpolant.
#
# However, the quantity that L2A and L2D are most interested in are the L1 data products. In other words, the laser-cleaned TDI combinations $X$, $Y$ and $Z$ for various generations of TDI. Below we will do a similar analysis but now considering the TDI variables.

# %%
from tqdm import tqdm as tqdm
order = 45
results_TDI_testing_N_nans = []

N_nans_in_telem_values = np.logspace(0, 2, num=50, dtype=int)  # Logarithmic spacing from 1 to 10000

for N_nans in tqdm(N_nans_in_telem_values):
    # Construct masking function
    masking_function = construct_mask_single_gap(N_nans, length=simlen)
        
    # Generate telemetry with gaps
    data_w_gaps = nanify_telemetry_variables(
        data, masking_function
    )
        
    # Compute eta variables with gaps
    etas_w_gaps_nans = compute_etas(
        data_w_gaps, order = 45, unit = "frequency"
    )
    TDI_X = []
    for gen in range(1,3):
        # rot = 0 stands for TDI X variable 
        result = compute_factorized_michelson(
            data_w_gaps, etas = etas_w_gaps_nans, rot = 0, order = order, generation = gen
    )
        TDI_X.append(result)
        
    # Calculate N_nans and widening for lolipops
    N_nans_in_TDI = [np.sum(np.isnan(TDI_X[i])) for i in range(len(TDI_X))]
    N_nans_in_X1_pytdi = N_nans_in_TDI[0] 
    N_nans_in_X2_pytdi = N_nans_in_TDI[1] 

    widening_gap_X1_pytdi = N_nans_in_X1_pytdi - N_nans
    widening_gap_X2_pytdi = N_nans_in_X2_pytdi - N_nans
        
    # Calculate N_nans and widening for theoretical model
    _, N_nans_in_X1_theory = widening_gap_X1(order, N_nans, delay)
    _, N_nans_in_X2_theory = widening_gap_X2(order, N_nans, delay)

    widening_gap_X1_theory = N_nans_in_X1_theory - N_nans
    widening_gap_X2_theory = N_nans_in_X2_theory - N_nans
        
    # Append results to the list
    results_TDI_testing_N_nans.append({
        "N_nans": N_nans,
        "N_nans_in_X1_pytdi": N_nans_in_X1_pytdi,
        "N_nans_in_X2_pytdi": N_nans_in_X2_pytdi,
        "widening_gap_X1_pytdi": widening_gap_X1_pytdi,
        "widening_gap_X2_pytdi": widening_gap_X2_pytdi,
        "N_nans_in_X1_theory": N_nans_in_X1_theory,
        "N_nans_in_X2_theory": N_nans_in_X2_theory,
        "widening_gap_X1_theory": widening_gap_X1_theory,
        "widening_gap_X2_theory": widening_gap_X2_theory
    })
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]2025-07-16 11:35:02,893 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:35:02,894 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:35:03,005 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:35:03,006 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:35:03,118 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:35:03,119 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:35:03,228 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:35:03,229 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:35:03,306 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:35:03,306 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:35:03,383 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:35:03,384 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:35:03,462 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 11:35:03,463 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41aa50>'
# 2025-07-16 11:35:03,463 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a
- INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a7802c0>'
# 2025-07-16 11:35:56,868 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a7802c0>'
# 2025-07-16 11:35:56,910 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-07-16 11:35:56,911 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a7802c0>'
# 2025-07-16 11:35:56,913 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a7802c0>'
# 2025-07-16 11:35:56,957 - INFO - Initializing combination with components '{'arm_a': [(1, [])], 'arm_b': [(1, ['D_12', 'D_21'])]}'
# 2025-07-16 11:35:56,957 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a7860f0>'
# 2025-07-16 11:35:56,966 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a7860f0>'
# 2025-07-16 11:35:57,013 - INFO - Initializing combination with components '{'arm_a': [(1, ['D_13', 'D_31'])], 'arm_b': [(1, [])]}'
# 2025-07-16 11:35:57,014 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a7e0>'
# 2025-07-16 11:35:57,023 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a7e0>'
# 2025-07-16 11:35:57,071 - INFO - Initializing combination with components '{'roundtrip_a': [(-1, []), (1, ['D_13', 'D_31', 'D_12', 'D_21'])], 'roundtrip_b': [(1, []), (-1, ['D_12', 'D_21', 'D_13', 'D_31'])]}'
# 2025-07-16 11:35:57,072 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc1da00>'
# 2025-07-16 11:35:57,122 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc1da00>'
# 100%|██████████| 50/50 [00:54<00:00,  1.09s/it]

# %% [markdown]
# # Plot the result
#
# What we will show here is that the gap widening in the TDI variables is weakly dependent on the duration of the gap. We have a similar plot for the eta variables above.

# %%
import matplotlib.pyplot as plt

# Extract data from results
N_nans_values = [result["N_nans"] for result in results_TDI_testing_N_nans]
widening_gap_X1_pytdi = [result["widening_gap_X1_pytdi"] for result in results_TDI_testing_N_nans]
widening_gap_X2_pytdi = [result["widening_gap_X2_pytdi"] for result in results_TDI_testing_N_nans]
widening_gap_X1_theory = [result["widening_gap_X1_theory"] for result in results_TDI_testing_N_nans]
widening_gap_X2_theory = [result["widening_gap_X2_theory"] for result in results_TDI_testing_N_nans]

# Create the figure and subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot X1 results on the left subplot
ax1.plot(
    N_nans_values, widening_gap_X1_pytdi, 
    label="PyTDI (X1)", linestyle="-", color="magenta"
)
ax1.plot(
    N_nans_values, widening_gap_X1_theory, 
    label="Theory (X1)", linestyle="--", marker="o", color="blue"
)
ax1.set_xscale("log")
ax1.set_xlabel("Number of NaNs in telemetry", fontsize=14)
ax1.set_ylabel("Gap Augmentation", fontsize=14)
ax1.set_title("Gap Widening: X1 Variables", fontsize=16)
ax1.legend(fontsize=16, loc="upper left")
ax1.grid(True, which="both", linestyle="--", linewidth=0.5)
ax1.tick_params(axis="both", which="major", labelsize=12)

# Plot X2 results on the right subplot
ax2.plot(
    N_nans_values, widening_gap_X2_pytdi, 
    label="PyTDI (X2)", linestyle="-", color="black"
)
ax2.plot(
    N_nans_values, widening_gap_X2_theory, 
    label="Theory (X2)", linestyle="--", marker="s", color="green"
)
ax2.set_xscale("log")
ax2.set_xlabel("Number of NaNs in telemetry", fontsize=14)
# ax2.set_ylabel("Widening of Gap in X2 Variables", fontsize=14)
ax2.set_title("Gap Widening: X2 Variables", fontsize=16)
ax2.legend(fontsize=16, loc="upper left")
ax2.grid(True, which="both", linestyle="--", linewidth=0.5)
ax2.tick_params(axis="both", which="major", labelsize=16)

# Adjust layout and show the plot
plt.tight_layout()
# plt.savefig("../Plots/gap_widening_comparison_TDI_subplots.png", dpi=300)  # Save as a high-resolution image
plt.show()

# %%
# Plot the results in seconds
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt

# Extract data from results
N_nans_values = [dt*result["N_nans"] for result in results_TDI_testing_N_nans]
widening_gap_X1_pytdi = [dt*result["widening_gap_X1_pytdi"] for result in results_TDI_testing_N_nans]
widening_gap_X2_pytdi = [dt*result["widening_gap_X2_pytdi"] for result in results_TDI_testing_N_nans]
widening_gap_X1_theory = [dt*result["widening_gap_X1_theory"] for result in results_TDI_testing_N_nans]
widening_gap_X2_theory = [dt*result["widening_gap_X2_theory"] for result in results_TDI_testing_N_nans]

# Create the figure and subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot X1 results on the left subplot
ax1.plot(
    N_nans_values, widening_gap_X1_pytdi, 
    label="PyTDI (X1)", linestyle="-", color="magenta"
)
ax1.plot(
    N_nans_values, widening_gap_X1_theory, 
    label="Theory (X1)", linestyle="--", marker="o", color="blue"
)
ax1.set_xscale("log")
ax1.set_xlabel("Gap duration in telemetry [s]", fontsize=14)
ax1.set_ylabel("Gap Augmentation [s]", fontsize=14)
ax1.set_title("Gap Widening: X1 Variables", fontsize=16)
ax1.legend(fontsize=16, loc="upper left")
ax1.grid(True, which="both", linestyle="--", linewidth=0.5)
ax1.tick_params(axis="both", which="major", labelsize=12)

# Plot X2 results on the right subplot
ax2.plot(
    N_nans_values, widening_gap_X2_pytdi, 
    label="PyTDI (X2)", linestyle="-", color="black"
)
ax2.plot(
    N_nans_values, widening_gap_X2_theory, 
    label="Theory (X2)", linestyle="--", marker="s", color="green"
)
ax2.set_xscale("log")
ax2.set_xlabel("Gap duration in telemetry [s]", fontsize=14)
# ax2.set_ylabel("Widening of Gap in X2 Variables", fontsize=14)
ax2.set_title("Gap Widening: X2 Variables", fontsize=16)
ax2.legend(fontsize=16, loc="upper left")
ax2.grid(True, which="both", linestyle="--", linewidth=0.5)
ax2.tick_params(axis="both", which="major", labelsize=16)

# Adjust layout and show the plot
plt.tight_layout()
# plt.savefig("../Plots/gap_widening_comparison_TDI_subplots.png", dpi=300)  # Save as a high-resolution image
plt.show()

# %%
# Create the figure and subplots
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

# Plot X2 results on the left subplot
ax.plot(
    N_nans_values, widening_gap_X2_pytdi, 
    label="PyTDI (X1)", linestyle="-", color="magenta"
)
ax.plot(
    N_nans_values, widening_gap_X2_theory, 
    label="Theory (X1)", linestyle="--", marker="o", color="blue"
)
ax.set_xscale("log")
ax.set_xlabel("Gap duration in telemetry [s]", fontsize=14)
ax.set_ylabel("Gap Augmentation [s]", fontsize=14)
ax.set_title("Gap Widening: X1 Variables", fontsize=16)
ax.legend(fontsize=16, loc="upper left")
ax.grid(True, which="both", linestyle="--", linewidth=0.5)
ax.tick_params(axis="both", which="major", labelsize=12)

# %%
TDI_results_by_order = {}

# Define the gap configurations and range of orders
gap_configurations = [1, 10, 25]
orders = range(25, 81, 2)  # From 25 to 81 inclusive

# Loop over each gap configuration
for N_nans in gap_configurations:
    TDI_results_by_order[N_nans] = []  # Initialize results for this gap configuration
    # Construct masking function
    masking_function = construct_mask_single_gap(N_nans, length=simlen)
    
    for order in tqdm(orders):
        
        # Generate telemetry with gaps
        data_w_gaps = nanify_telemetry_variables(
            data, masking_function
        )
        
        # Compute eta variables with gaps
        etas_w_gaps_nans = compute_etas(
            data_w_gaps, order, unit="frequency"
        )        
        # Compute TDI variables for two generations
        TDI_X = []
        for gen in range(1, 3):
            result = compute_factorized_michelson(
                data_w_gaps, etas=etas_w_gaps_nans, rot=0, order=order, generation=gen
            )
            TDI_X.append(result)
        
        # Calculate N_nans and widening for pytdi
        N_nans_in_TDI = [np.sum(np.isnan(TDI_X[i])) for i in range(len(TDI_X))]
        widening_gap_X1_pytdi = N_nans_in_TDI[0] - N_nans
        widening_gap_X2_pytdi = N_nans_in_TDI[1] - N_nans

        # Calculate N_nans and widening for theoretical model
        _, N_nans_in_X1_theory = widening_gap_X1(order, N_nans, delay)
        _, N_nans_in_X2_theory = widening_gap_X2(order, N_nans, delay)
        widening_gap_X1_theory = N_nans_in_X1_theory - N_nans
        widening_gap_X2_theory = N_nans_in_X2_theory - N_nans
        
        # Append results to the list for this gap configuration
        TDI_results_by_order[N_nans].append({
            "order": order,
            "widening_gap_X1_pytdi": widening_gap_X1_pytdi,
            "widening_gap_X2_pytdi": widening_gap_X2_pytdi,
            "widening_gap_X1_theory": widening_gap_X1_theory,
            "widening_gap_X2_theory": widening_gap_X2_theory,
        })
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]2025-07-16 11:37:57,022 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:37:57,023 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:37:57,078 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:37:57,079 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:37:57,132 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:37:57,133 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:37:57,179 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:37:57,180 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:37:57,216 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:37:57,216 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:37:57,249 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:37:57,249 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:37:57,282 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 11:37:57,283 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fb8b110>'
# 2025-07-16 11:37:57,283 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fb8b110>'
# 2025-07-16 11:37:57,299 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-07-16 11:37:57,299 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fe7b8c0>'
# 2025-07-16 11:37:57,299 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fe7b8c0>'
# 2025-07-16 11:37:57,318 - INFO - Initializing combination with components '{'x_arm_1': [(-1, []), (1, ['D_13', 'D_31'])], 'x_arm_2': [(1, []), (-1, ['D_12', 'D_21'])]}'
# 2025-07-16 11:37:57,319 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fb8b110>'
# 2025-07-16 11:37:57,332 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fb8b110>'
# 2025-07-16 11:37:57,366 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 11:37:57,366 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc7e360>'
# 2025-07-16 11:37:57,366 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc7e360>'
# 2025-07-16 11:37:57,381 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-07-16 11:37:57,381 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fe9eb70>'
# 2025-07-16 11:37:57,381 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fe9eb70>'
# 2025-07-16 11:37:57,395 - INFO - Initializing combination with components '{'arm_a': [(1, [])], 'arm_b': [(1, ['D_12', 'D_21'])]}'
# 2025-07-16 11:37:57,396 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fdcff80>'
# 2025-07-16 11:37:57,402 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fdcff80>'
# 2025-07-16 11:37:57,419 - INFO - Initializing combination with components '{'arm_a': [(1, ['D_13', 'D_31'])], 'arm_b': [(1, [])]}'
# 2025-07-16 11:37:57,419 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fb8b110>'
# 2025-07-16 11:37:57,427 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fb8b110>'
# 2025-07-16 11:37:57,445 - INFO - Initializing combination with components '{'roundtrip_a': [(-1, []), (1, ['D_13', 'D_31', 'D_12', 'D_21'])], 'roundtrip_b': [(1, []), (-1, ['D_12', 'D_21', 'D_13', 'D_31'])]}'
# 2025-07-16 11:37:57,445 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fb8b5f0>'
# 2025-07-16 11:37:57,486 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fb8b5f0>'
#   4%|▎         | 1/28 [00:00<00:13,  1.97it/s]2025-07-16 11:37:57,529 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:37:57,529 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:37:57,579 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:37:57,580 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:37:57,633 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:37:57,634 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:37:57,699 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:37:57,700 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:37:57,742 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:37:57,743 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:37:57,785 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:37:57,785 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:37:57,827 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 11:37:57,827 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc938c0>'
# 2025-07-16 11:37:57,827 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc938c0>'
# 2025-07-16 11:37:57,847 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-07-16 11:37:57,848 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fb6a510>'
# 2025-07-16 11:37:57,848 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fb6a510>'
# 2025-07-16 11:37:57,866 - INFO - Initializing combination with components '{'x_arm_1': [(-1, []), (1, ['D_13', 'D_31'])], 'x_arm_2': [(1, []), (-1, ['D_12', 'D_21'])]}'
# 2025-07-16 11:37:57,866 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc93530>'
# 2025-07-16 11:37:57,881 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc93530>'
# 2025-07-16 11:37:57,920 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 11:37:57,921 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fdce360>'
# 2025-07-16 11:37:57,921 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fdce360>'
# 2025-07-16 11:37:57,940 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-07-16 11:37:57,941 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fb6a510>'
# 2025-07-16 11:37:57,941 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fb6a510>'
# 2025-07-16 11:37:57,958 - INFO - Initializing combination with components '{'arm_a': [(1, [])], 'arm_b': [(1, ['D_12', 'D_21'])]}'
# 2025-07-16 11:37:57,959 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fb6a510>'
# 2025-07-16 11:37:57,966 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fb6a510>'
# 2025-07-16 11:37:57,986 - INFO - Initializing combination with components '{'arm_a': [(1, ['D_13', 'D_31'])], 'arm_b': [(1, [])]}'
# 2025-07-16 11:37:57,986 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a7fb5f0>'
# 2025-07-16 11:37:57,993 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a7fb5f0>'
# 2025-07-16 11:37:58,012 - INFO - Initializing combination with components '{'roundtrip_a': [(-1, []), (1, ['D_13', 'D_31', 'D_12', 'D_21'])], 'roundtrip_b': [(1, []), (-1, ['D_12', 'D_21', 'D_13', 'D_31'])]}'
# 2025-07-16 11:37:58,013 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a7bce30>'
# 2025-07-16 11:37:58,048 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a7bce30>'
#   7%|▋         | 2/28 [00:01<00:14,  1.84it/s]2025-07-16 11:37:58,099 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:37:58,100 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:37:58,171 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:37:58,172 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:37:58,239 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:37:58,240 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:37:58,318 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:37:58,318 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:37:58,365 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:37:58,366 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:37:58,407 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:37:58,408 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:37:58,451 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 11:37:58,452 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc29a90>'
# 2025-07-16 11:37:58,452 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc29a90>'
# 2025-07-16 11:37:58,473 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-07-16 11:37:58,474 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc2b260>'
# 2025-07-16 11:37:58,474 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc2b260>'
# 2025-07-16 11:37:58,494 - INFO - Initializing combination with components '{'x_arm_1': [(-1, []), (1, ['D_13', 'D_31'])], 'x_arm_2': [(1, []), (-1, ['D_12', 'D_21'])]}'
# 2025-07-16 11:37:58,494 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14ff19ac0>'
# 2025-07-16 11:37:58,511 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14ff19ac0>'
# 2025-07-16 11:37:58,553 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 11:37:58,554 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc29a90>'
# 2025-07-16 11:37:58,554 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc29a90>'
# 2025-07-16 11:37:58,576 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-07-16 11:37:58,577 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc29a90>'
# 2025-07-16 11:37:58,577 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc29a90>'
# 2025-07-16 11:37:58,596 - INFO - Initializing combination with components '{'arm_a': [(1, [])], 'arm_b': [(1, ['D_12', 'D_21'])]}'
# 2025-07-16 11:37:58,597 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc2a390>'
# 2025-07-16 11:37:58,603 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc2a390>'
# 2025-07-16 11:37:58,626 - INFO - Initializing combination with components '{'arm_a': [(1, ['D_13', 'D_31'])], 'arm_b': [(1, [])]}'
# 2025-07-16 11:37:58,626 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14ff19ac0>'
# 2025-07-16 11:37:58,632 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14ff19ac0>'
# 2025-07-16 11:37:58,655 - INFO - Initializing combination with components '{'roundtrip_a': [(-1, []), (1, ['D_13', 'D_31', 'D_12', 'D_21'])], 'roundtrip_b': [(1, []), (-1, ['D_12', 'D_21', 'D_13', 'D_31'])]}'
# 2025-07-16 11:37:58,655 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc9dc70>'
# 2025-07-16 11:37:58,693 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc9dc70>'
#  11%|█         | 3/28 [00:01<00:14,  1.69it/s]2025-07-16 11:37:58,746 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:37:58,746 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:37:58,815 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:37:58,816 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:37:58,881 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:37:58,882 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:37:58,947 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:37:58,948 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:37:58,998 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:37:58,999 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:37:59,044 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:37:59,045 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:37:59,092 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 11:37:59,093 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fb8b110>'
# 2025-07-16 11:37:59,093 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fb8b110>'
# 2025-07-16 11:37:59,117 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-07-16 11:37:59,117 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fd05b20>'
# 2025-07-16 11:37:59,118 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fd05b20>'
# 2025-07-16 11:37:59,140 - INFO - Initializing combination with components '{'x_arm_1': [(-1, []), (1, ['D_13', 'D_31'])], 'x_arm_2': [(1, []), (-1, ['D_12', 'D_21'])]}'
# 2025-07-16 11:37:59,140 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fdf0080>'
# 2025-07-16 11:37:59,152 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fdf0080>'
# 2025-07-16 11:37:59,198 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 11:37:59,198 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fdf0080>'
# 2025-07-16 11:37:59,198 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fdf0080>'
# 2025-07-16 11:37:59,220 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-07-16 11:37:59,220 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fd05b20>'
# 2025-07-16 11:37:59,221 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fd05b20>'
# 2025-07-16 11:37:59,245 - INFO - Initializing combination with components '{'arm_a': [(1, [])], 'arm_b': [(1, ['D_12', 'D_21'])]}'
# 2025-07-16 11:37:59,246 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a729070>'
# 2025-07-16 11:37:59,253 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a729070>'
# 2025-07-16 11:37:59,276 - INFO - Initializing combination with components '{'arm_a': [(1, ['D_13', 'D_31'])], 'arm_b': [(1, [])]}'
# 2025-07-16 11:37:59,276 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a729a90>'
# 2025-07-16 11:37:59,285 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a729a90>'
# 2025-07-16 11:37:59,309 - INFO - Initializing combination with components '{'roundtrip_a': [(-1, []), (1, ['D_13', 'D_31', 'D_12', 'D_21'])], 'roundtrip_b': [(1, []), (-1, ['D_12', 'D_21', 'D_13', 'D_31'])]}'
# 2025-07-16 11:37:59,310 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc9c5c0>'
# 2025-07-16 11:37:59,351 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc9c5c0>'
#  14%|█▍        | 4/28 [00:02<00:14,  1.62it/s]2025-07-16 11:37:59,408 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:37:59,408 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:37:59,481 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:37:59,482 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:37:59,552 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:37:59,552 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:37:59,627 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:37:59,628 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:37:59,679 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:37:59,679 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:37:59,730 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:37:59,730 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:37:59,779 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 11:37:59,780 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a7bca40>'
# 2025-07-16 11:37:59,780 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a7bca40>'
# 2025-07-16 11:37:59,805 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-07-16 11:37:59,805 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fd05b20>'
# 2025-07-16 11:37:59,806 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14f
- INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc90bc0>'
# 2025-07-16 11:38:04,374 - INFO - Initializing combination with components '{'arm_a': [(1, [])], 'arm_b': [(1, ['D_12', 'D_21'])]}'
# 2025-07-16 11:38:04,374 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fcd9c40>'
# 2025-07-16 11:38:04,383 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fcd9c40>'
# 2025-07-16 11:38:04,425 - INFO - Initializing combination with components '{'arm_a': [(1, ['D_13', 'D_31'])], 'arm_b': [(1, [])]}'
# 2025-07-16 11:38:04,425 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a7d8380>'
# 2025-07-16 11:38:04,433 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a7d8380>'
# 2025-07-16 11:38:04,472 - INFO - Initializing combination with components '{'roundtrip_a': [(-1, []), (1, ['D_13', 'D_31', 'D_12', 'D_21'])], 'roundtrip_b': [(1, []), (-1, ['D_12', 'D_21', 'D_13', 'D_31'])]}'
# 2025-07-16 11:38:04,472 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc1d970>'
# 2025-07-16 11:38:04,514 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc1d970>'
#  36%|███▌      | 10/28 [00:07<00:15,  1.13it/s]2025-07-16 11:38:04,592 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:38:04,593 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:38:04,706 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:38:04,706 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:38:04,821 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:38:04,823 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:38:04,938 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:38:04,938 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:38:05,017 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:38:05,017 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:38:05,097 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:38:05,098 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:38:05,174 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 11:38:05,174 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc9f830>'
# 2025-07-16 11:38:05,175 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc9f830>'
# 2025-07-16 11:38:05,211 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-07-16 11:38:05,212 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc3fce0>'
# 2025-07-16 11:38:05,212 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc3fce0>'
# 2025-07-16 11:38:05,251 - INFO - Initializing combination with components '{'x_arm_1': [(-1, []), (1, ['D_13', 'D_31'])], 'x_arm_2': [(1, []), (-1, ['D_12', 'D_21'])]}'
# 2025-07-16 11:38:05,252 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc3fce0>'
# 2025-07-16 11:38:05,266 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc3fce0>'
# 2025-07-16 11:38:05,341 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 11:38:05,341 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc3fce0>'
# 2025-07-16 11:38:05,342 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc3fce0>'
# 2025-07-16 11:38:05,379 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-07-16 11:38:05,379 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a7fa030>'
# 2025-07-16 11:38:05,380 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a7fa030>'
# 2025-07-16 11:38:05,420 - INFO - Initializing combination with components '{'arm_a': [(1, [])], 'arm_b': [(1, ['D_12', 'D_21'])]}'
# 2025-07-16 11:38:05,420 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fdce9f0>'
# 2025-07-16 11:38:05,428 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fdce9f0>'
# 2025-07-16 11:38:05,468 - INFO - Initializing combination with components '{'arm_a': [(1, ['D_13', 'D_31'])], 'arm_b': [(1, [])]}'
# 2025-07-16 11:38:05,469 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a7fa030>'
# 2025-07-16 11:38:05,476 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a7fa030>'
# 2025-07-16 11:38:05,515 - INFO - Initializing combination with components '{'roundtrip_a': [(-1, []), (1, ['D_13', 'D_31', 'D_12', 'D_21'])], 'roundtrip_b': [(1, []), (-1, ['D_12', 'D_21', 'D_13', 'D_31'])]}'
# 2025-07-16 11:38:05,516 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc916d0>'
# 2025-07-16 11:38:05,555 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc916d0>'
#  39%|███▉      | 11/28 [00:08<00:15,  1.07it/s]2025-07-16 11:38:05,638 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:38:05,639 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:38:05,760 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:38:05,760 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:38:05,882 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:38:05,883 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:38:06,004 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:38:06,004 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:38:06,088 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# ...
# 2025-07-16 11:39:45,816 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:39:45,816 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:39:45,998 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 11:39:45,998 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc2af30>'
# 2025-07-16 11:39:45,999 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc2af30>'
# 2025-07-16 11:39:46,082 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-07-16 11:39:46,082 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc92c30>'
# 2025-07-16 11:39:46,083 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc92c30>'
# 2025-07-16 11:39:46,169 - INFO - Initializing combination with components '{'x_arm_1': [(-1, []), (1, ['D_13', 'D_31'])], 'x_arm_2': [(1, []), (-1, ['D_12', 'D_21'])]}'
# 2025-07-16 11:39:46,169 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc28980>'
# 2025-07-16 11:39:46,183 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc28980>'
# 2025-07-16 11:39:46,359 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 11:39:46,360 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fb88050>'
# 2025-07-16 11:39:46,360 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fb88050>'
# 2025-07-16 11:39:46,447 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-07-16 11:39:46,447 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc7f830>'
# 2025-07-16 11:39:46,447 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc7f830>'
# 2025-07-16 11:39:46,537 - INFO - Initializing combination with components '{'arm_a': [(1, [])], 'arm_b': [(1, ['D_12', 'D_21'])]}'
# 2025-07-16 11:39:46,538 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14febf6e0>'
# 2025-07-16 11:39:46,545 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14febf6e0>'
# 2025-07-16 11:39:46,628 - INFO - Initializing combination with components '{'arm_a': [(1, ['D_13', 'D_31'])], 'arm_b': [(1, [])]}'
# 2025-07-16 11:39:46,629 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc92c30>'
# 2025-07-16 11:39:46,636 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc92c30>'
# 2025-07-16 11:39:46,724 - INFO - Initializing combination with components '{'roundtrip_a': [(-1, []), (1, ['D_13', 'D_31', 'D_12', 'D_21'])], 'roundtrip_b': [(1, []), (-1, ['D_12', 'D_21', 'D_13', 'D_31'])]}'
# 2025-07-16 11:39:46,724 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fdcd880>'
# 2025-07-16 11:39:46,762 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fdcd880>'
#  89%|████████▉ | 25/28 [00:31<00:06,  2.03s/it]2025-07-16 11:39:46,944 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:39:46,944 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 11:39:47,219 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:39:47,219 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 11:39:47,488 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:39:47,488 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 11:39:47,744 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:39:47,744 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 11:39:47,918 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:39:47,919 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 11:39:48,097 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:39:48,098 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 11:39:48,281 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 11:39:48,282 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc930b0>'
# 2025-07-16 11:39:48,282 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14f
- INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc3dee0>'
# 2025-07-16 11:39:53,938 - INFO - Initializing combination with components '{'arm_a': [(1, ['D_13', 'D_31'])], 'arm_b': [(1, [])]}'
# 2025-07-16 11:39:53,939 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a7bf350>'
# 2025-07-16 11:39:53,945 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a7bf350>'
# 2025-07-16 11:39:54,044 - INFO - Initializing combination with components '{'roundtrip_a': [(-1, []), (1, ['D_13', 'D_31', 'D_12', 'D_21'])], 'roundtrip_b': [(1, []), (-1, ['D_12', 'D_21', 'D_13', 'D_31'])]}'
# 2025-07-16 11:39:54,044 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc7ea80>'
# 2025-07-16 11:39:54,087 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc7ea80>'
# 100%|██████████| 28/28 [00:39<00:00,  1.39s/it]

# %%
import matplotlib.pyplot as plt
plt.clf()

# Create the figure and subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Define markers and colors for each gap configuration
markers = ["o", "s", "D"]
colors = ["blue", "orange", "green"]

# Loop through each gap configuration and plot the results for X1
for idx, (N_nans, results) in enumerate(TDI_results_by_order.items()):
    # Extract data for this N_nans configuration
    orders = [result["order"] for result in results]
    widening_gap_X1_pytdi = [result["widening_gap_X1_pytdi"] for result in results]
    widening_gap_X1_theory = [result["widening_gap_X1_theory"] for result in results]
    
    # Plot X1 results on the left subplot
    ax1.plot(
        orders, widening_gap_X1_pytdi, 
        label=f"pytdi X1 nans={N_nans}", 
        linestyle="-", color=colors[idx], zorder=1
    )
    ax1.plot(
        orders, widening_gap_X1_theory, 
        label=f"Prediction X1 nans={N_nans}", 
        marker=markers[idx], linestyle="--", color=colors[idx], zorder=2
    )

# Customize the left subplot (X1)
ax1.set_xlabel("Order of Interpolant", fontsize=25)
ax1.set_ylabel(r"Gap Augmentation", fontsize=25)
# ax1.set_title(r"Gap Widening: $X_1$ Variables", fontsize=20)
ax1.legend(fontsize=16, loc="upper left")
ax1.grid(True, linestyle="--", linewidth=0.5)
ax1.tick_params(axis="both", which="major", labelsize=16)

# Loop through each gap configuration and plot the results for X2
for idx, (N_nans, results) in enumerate(TDI_results_by_order.items()):
    # Extract data for this N_nans configuration
    orders = [result["order"] for result in results]
    widening_gap_X2_pytdi = [result["widening_gap_X2_pytdi"] for result in results]
    widening_gap_X2_theory = [result["widening_gap_X2_theory"] for result in results]
    
    # Plot X2 results on the right subplot
    ax2.plot(
        orders, widening_gap_X2_pytdi, 
        label=f"pytdi X2 nans={N_nans}", 
        linestyle="-", color=colors[idx], zorder=1, alpha=0.7
    )
    ax2.plot(
        orders, widening_gap_X2_theory, 
        label=f"Prediction X2 nans={N_nans}", 
        marker=markers[idx], linestyle="--", color=colors[idx], zorder=2, alpha=0.7
    )

# Customize the right subplot (X2)
ax2.set_xlabel("Order of Interpolant", fontsize=20)
# ax2.set_title(r"Gap Widening: $X_2$ Variables", fontsize=20)
ax2.legend(fontsize=16, loc="upper left")
ax2.grid(True, linestyle="--", linewidth=0.5)
ax2.tick_params(axis="both", which="major", labelsize=16)

# Adjust layout and show the plot
plt.tight_layout()
# plt.savefig("../Plots/gap_widening_comparison_TDI_subplots_change_gap_duration.png", dpi=300)  # Save as a high-resolution image
plt.show()

# %% [markdown]
# # The formulas check out
#
# The formulas work extremely well for standard orders of interpolants $\mathcal{O}(L) \gtrsim 25$ providing that the missing data is contiguous. In other words, the \texttt{nans} are next to eachother. The formula *will* break down if you have multiple gaps that are very close to eachother. This is because as the nans propagate through the pipeline, the gated segments will start eating onto eachother. This means that the formula, predicting the total number of lost data will always over-estimate the loss, rather than underestimate it. This is good, we are being conservative.
#
# ## The future goals
#
# We will have multiple gaps of various durations. The question is how accurately (and quickly) can I predict the overall gap augmentation due to the TDI pipeline? Now I will use a generic masking function to do this.

# %%
# Import the necessary functions from the multi_gap_utils module
# Assuming the functions are defined in a file named multi_gap_utils.py in the same directory
sys.path.append("..")  # if multi_gap_utils.py is in the parent directory
from utility_funcs.multi_gap_utils import (
    mask_eta, 
    mask_TDI_X,
    approx_total_nans_from_nan_blocks_eta,
    approx_total_nans_from_nan_blocks_X
)

# %%
# Consider now a longer simulation 

simlen_multi_gap = 1_050_000

instr_3_days_static = Instrument(size=simlen_multi_gap, dt = 0.25, orbits = 'static_orbits.h5', seed=1234)

instr_3_days_static.disable_all_noises(excluding=['laser', 'test-mass', 'oms']) 
instr_3_days_static.simulate()

instr_3_days_static.write('static_3_day_simulation.h5', mode='w')
# Out:
# 2025-07-16 11:41:06,589 - INFO - Initializing instrumental simulation
# 2025-07-16 11:41:06,607 - INFO - Computing measurement time vector (size=1050000, dt=0.25)
# 2025-07-16 11:41:06,609 - INFO - Computing physics time vector (size=4200000, dt=0.0625)
# 2025-07-16 11:41:06,616 - INFO - Computing telemetry time vector (size=5, dt=86400.0)
# 2025-07-16 11:41:06,630 - INFO - Using orbit file 'static_orbits.h5'
# 2025-07-16 11:41:09,227 - INFO - Using pre-defined locking configuration 'N1-12'
# 2025-07-16 11:41:09,227 - WARNING - Using default set of locking beatnote frequencies; this might cause interferometric beatnote frequencies to fall outside the requirement range of 5..25 MHz
# 2025-07-16 11:41:09,227 - INFO - Designing antialiasing filter ('kaiser', 240, 1.1, 2.9)
# 2025-07-16 11:41:09,228 - INFO - Starting simulation
# 2025-07-16 11:41:09,228 - INFO - Generating clock noise
# 2025-07-16 11:41:09,302 - INFO - Generating modulation noise
# 2025-07-16 11:41:09,302 - INFO - Generating backlink noise
# 2025-07-16 11:41:09,303 - INFO - Generating test-mass acceleration noise
# 2025-07-16 11:41:11,002 - INFO - Generating ranging noise
# 2025-07-16 11:41:11,002 - INFO - Generating OMS noise
# 2025-07-16 11:41:16,102 - INFO - Generating DWS measurement noise
# 2025-07-16 11:41:16,103 - INFO - Generating MOSA longitudinal jitters
# 2025-07-16 11:41:16,103 - INFO - Generating spacecraft angular jitters
# 2025-07-16 11:41:16,103 - INFO - Generating MOSA angular jitters
# 2025-07-16 11:41:16,103 - INFO - Computing MOSA total angular jitters
# 2025-07-16 11:41:16,104 - INFO - Computing tilt-to-length couplings
# 2025-07-16 11:41:16,572 - INFO - Simulating local beams
# 2025-07-16 11:41:16,572 - INFO - Generating laser noise for laser 12
# 2025-07-16 11:41:19,796 - INFO - Propagating local beams to distant MOSAs
# 2025-07-16 11:41:58,646 - INFO - Propagating local beams to adjacent MOSAs
# 2025-07-16 11:41:58,673 - INFO - Propagating local beams to inter-spacecraft interferometers
# 2025-07-16 11:41:58,674 - INFO - Propagating distant beams to inter-spacecraft interferometers
# 2025-07-16 11:41:58,674 - INFO - Computing inter-spacecraft beatnotes on TPS
# 2025-07-16 11:41:58,862 - INFO - Computing inter-spacecraft DWS measurements on TPS
# 2025-07-16 11:41:58,863 - INFO - Computing measured pseudo-ranges on TPS
# 2025-07-16 11:41:58,894 - INFO - Propagating local beams to test-mass interferometers
# 2025-07-16 11:41:59,130 - INFO - Propagating adjacent beams to test-mass interferometers
# 2025-07-16 11:41:59,130 - INFO - Computing test-mass beatnotes on TPS
# 2025-07-16 11:41:59,304 - INFO - Propagating local beams to reference interferometers
# 2025-07-16 11:41:59,304 - INFO - Propagating adjacent beams to reference interferometers
# 2025-07-16 11:41:59,304 - INFO - Computing reference beatnotes on TPS
# 2025-07-16 11:41:59,468 - INFO - Inverting SCET with respect to TPS
# 2025-07-16 11:41:59,503 - INFO - Sampling inter-spacecraft beatnotes to SCET grid
# 2025-07-16 11:41:59,866 - INFO - Sampling measured pseudo-ranges to SCET grid
# 2025-07-16 11:41:59,902 - INFO - Sampling test-mass beatnotes to SCET grid
# 2025-07-16 11:42:00,153 - INFO - Sampling reference beatnotes to SCET grid
# 2025-07-16 11:42:00,405 - INFO - Applying electronic delays
# 2025-07-16 11:42:00,406 - INFO - Filtering beatnotes
# 2025-07-16 11:42:05,293 - INFO - Downsampling beatnotes
# 2025-07-16 11:42:05,293 - INFO - Computing total beatnote frequencies
# 2025-07-16 11:42:05,372 - INFO - Simulation complete
# 2025-07-16 11:42:05,396 - INFO - Writing simulation to 'static_3_day_simulation.h5'
# 2025-07-16 11:42:06,730 - INFO - Closing measurement file 'static_3_day_simulation.h5'

# %%
data_3_day_sim = Data.from_instrument(instr_3_days_static)
# Out:
# 2025-07-16 11:42:30,043 - INFO - Loading instrument object '<lisainstrument.instrument.Instrument object at 0x14a7bd910>'
# 2025-07-16 11:42:30,044 - WARNING - You are using LISA Instrument in a version that might not be fully supported
# 2025-07-16 11:42:30,045 - INFO - Initializing data object
# 2025-07-16 11:42:30,045 - INFO - Computing delay derivatives

# %% [markdown]
# # Define the overall masking function
#
# The masking function will take in a dictionary of gating functions

# %%
# Generate the mask with sampling interval 0.25 seconds

# Define the gap function 

# Construct gap class

sim_t = np.arange(0, simlen_multi_gap * dt, dt)

gap_definitions = {
    "planned": {
        "Instrumental Maintainance": {"rate_per_year": 5 * 260, "duration_hr": 0.0001*3.3}
    },
    "unplanned": {
        "Instrument breaks": {"rate_per_year": 3, "duration_hr": 60},
    }
}

# Initialise class with rates, and sampling properties.
generator_gap_3_day = GapMaskGenerator(
    sim_t,
    dt,
    gap_definitions,
    treat_as_nan=True,
    planseed=11_07_1993,
    unplanseed=16_12_1997
)

# Generate the mask full of gaps
full_mask_3_day = generator_gap_3_day.generate_mask(include_unplanned=False, include_planned=True)
N_nans_check = np.sum(np.isnan(full_mask_3_day))

extract_summary = generator_gap_3_day.summary(mask = full_mask_3_day)
from pprint import pprint
pprint(extract_summary['mask_analysis'])
# Out:
# {'duty_cycle_percent': np.float64(99.9962),
#  'number_of_gap_segments': 10,
#  'total_gap_hours': np.float64(0.0),
#  'total_gap_samples': 40}

# %%
plt.plot(full_mask_3_day)

# %%
# Let's compute the true number of nans in the eta variables
N_nans_multiple_gaps = np.sum(np.isnan(full_mask_3_day))

data_w_multi_gaps = nanify_telemetry_variables(data_3_day_sim, full_mask_3_day)
etas_w_multi_gaps = compute_etas(
    data_w_multi_gaps, order=order, unit="frequency"
)

LTT = data_w_multi_gaps.delays['d_12'][1000:][0]  # Take the mean LTT
delay_integer_fraction = LTT / dt  # Here we take the mean LTT. "samples"
eta_mask = mask_eta(full_mask_3_day, delay=delay_integer_fraction, order=order)

print("")
print("Doing things using pytdi")
N_nans_in_eta_w_multi_gaps_pytdi = np.sum(np.isnan(etas_w_multi_gaps["eta_12"]))
widening_gap_eta_pytdi = N_nans_in_eta_w_multi_gaps_pytdi - N_nans_multiple_gaps
print("Number of nans in the eta variables = ", N_nans_in_eta_w_multi_gaps_pytdi)
print("Overall widening of gap in eta variables = ", widening_gap_eta_pytdi)
print("")
print("Now doing things carefully but using theory")

N_nans_in_eta_w_multi_gaps_theory = np.sum(np.isnan(eta_mask))
widening_gap_eta_theory = N_nans_in_eta_w_multi_gaps_theory - N_nans_multiple_gaps
print("Number of nans in the eta variables = ", N_nans_in_eta_w_multi_gaps_theory)
print("Overall widening of gap in eta variables = ", widening_gap_eta_theory)

# Can I try to approximate this result?
print("")
print("Now using our quick approximation formula")
approx_nans_in_eta = approx_total_nans_from_nan_blocks_eta(full_mask_3_day, delay, lagrange_order=order, delay_number=1.0)

approx_N_nans_in_eta_w_multi_gaps_theory = np.sum(np.isnan(eta_mask))
approx_widening_gap_eta_theory = approx_N_nans_in_eta_w_multi_gaps_theory - N_nans_multiple_gaps
print("Approx number of nans in the eta variables = ", approx_N_nans_in_eta_w_multi_gaps_theory)
print("Overall widening of gap in eta variables = ", approx_widening_gap_eta_theory)
# Out:
# 2025-07-16 14:19:06,124 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 14:19:06,125 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# /opt/miniconda3/envs/pytdi_env/lib/python3.12/site-packages/pytdi/dsp.py:113: RuntimeWarning: invalid value encountered in cast
#   shift_ints = shift_ints.astype(int)
# 2025-07-16 14:19:07,218 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 14:19:07,220 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 14:19:08,316 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 14:19:08,317 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 14:19:09,408 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 14:19:09,410 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 14:19:10,133 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 14:19:10,135 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 14:19:10,865 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 14:19:10,866 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# Doing things using pytdi
# Number of nans in the eta variables =  530
# Overall widening of gap in eta variables =  490
#
# Now doing things carefully but using theory
# Number of nans in the eta variables =  530
# Overall widening of gap in eta variables =  490
#
# Now using our quick approximation formula
# Approx number of nans in the eta variables =  530
# Overall widening of gap in eta variables =  490

# %% [markdown]
# <!-- # Try to do the same thing but with TDI X variables for both generations -->

# %%
# Compute TDI variables for generation 1 and generation 2
order = 45
TDI_X = []
for gen in range(1, 3):
    result = compute_factorized_michelson(
    data_w_multi_gaps, etas = etas_w_multi_gaps, rot=0, order=order, generation=gen
    )
    TDI_X.append(result)
# Out:
# 2025-07-16 14:19:16,810 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 14:19:16,811 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x15a3868a0>'
# 2025-07-16 14:19:16,813 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x15a3868a0>'
# 2025-07-16 14:19:17,204 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-07-16 14:19:17,204 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x159814b90>'
# 2025-07-16 14:19:17,206 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x159814b90>'
# 2025-07-16 14:19:17,574 - INFO - Initializing combination with components '{'x_arm_1': [(-1, []), (1, ['D_13', 'D_31'])], 'x_arm_2': [(1, []), (-1, ['D_12', 'D_21'])]}'
# 2025-07-16 14:19:17,575 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fb6b800>'
# 2025-07-16 14:19:17,721 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fb6b800>'
# 2025-07-16 14:19:18,473 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 14:19:18,474 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a7d8bf0>'
# 2025-07-16 14:19:18,475 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a7d8bf0>'
# 2025-07-16 14:19:18,880 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-07-16 14:19:18,880 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a7d9dc0>'
# 2025-07-16 14:19:18,881 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a7d9dc0>'
# 2025-07-16 14:19:19,262 - INFO - Initializing combination with components '{'arm_a': [(1, [])], 'arm_b': [(1, ['D_12', 'D_21'])]}'
# 2025-07-16 14:19:19,262 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a7d9dc0>'
# 2025-07-16 14:19:19,354 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a7d9dc0>'
# 2025-07-16 14:19:19,752 - INFO - Initializing combination with components '{'arm_a': [(1, ['D_13', 'D_31'])], 'arm_b': [(1, [])]}'
# 2025-07-16 14:19:19,752 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a7d8bf0>'
# 2025-07-16 14:19:19,826 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a7d8bf0>'
# 2025-07-16 14:19:20,227 - INFO - Initializing combination with components '{'roundtrip_a': [(-1, []), (1, ['D_13', 'D_31', 'D_12', 'D_21'])], 'roundtrip_b': [(1, []), (-1, ['D_12', 'D_21', 'D_13', 'D_31'])]}'
# 2025-07-16 14:19:20,227 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc9c980>'
# 2025-07-16 14:19:20,655 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc9c980>'

# %%
N_nans_multiple_gaps = np.sum(np.isnan(full_mask_3_day))

X2_mask = mask_TDI_X(full_mask_3_day, delay_integer_fraction, order=order, generation=2)

check_N_nans_in_X2_theory = approx_total_nans_from_nan_blocks_X(full_mask_3_day, delay_integer_fraction, order=order, generation=2)

N_nans_using_X2_mask = np.sum(np.isnan(X2_mask))

N_nans_using_pytdi_X2 = np.sum(np.isnan(TDI_X[1]))

print("widening for TDI2 using pytdi ", N_nans_using_pytdi_X2 - N_nans_multiple_gaps)
print("widening for TDI2 using mask ", N_nans_using_X2_mask - N_nans_multiple_gaps)
print("widening for TDI2 using formulas ", check_N_nans_in_X2_theory - N_nans_multiple_gaps)
# Out:
# widening for TDI2 using pytdi  3500
# widening for TDI2 using mask  3500
# widening for TDI2 using formulas  3500

# %%
print("Using pytdi")
N_nans_in_X1_w_multi_gaps_pytdi = np.sum(np.isnan(TDI_X[0]))
N_nans_in_X2_w_multi_gaps_pytdi = np.sum(np.isnan(TDI_X[1]))

widening_gap_X1_pytdi = N_nans_in_X1_w_multi_gaps_pytdi - N_nans_multiple_gaps
widening_gap_X2_pytdi = N_nans_in_X2_w_multi_gaps_pytdi - N_nans_multiple_gaps
print("pytdi: Number of nans in X1 variables = ", N_nans_in_X1_w_multi_gaps_pytdi)
print("pytdi: Widening of gap in X1 variables = ", widening_gap_X1_pytdi)
print("pytdi: Number of nans in X2 variables = ", N_nans_in_X2_w_multi_gaps_pytdi)
print("pytdi: Widening of gap in X2 variables = ", widening_gap_X2_pytdi)

print("")
print("Now doing things carefully but using theory")
print("")

# Compute the masking function for X1 and X2 variables using formulas
X1_mask = mask_TDI_X(full_mask_3_day, delay, order=order, generation=1)
X2_mask = mask_TDI_X(full_mask_3_day, delay, order=order, generation=2)

N_nans_in_X1_w_multi_gaps_theory = np.sum(np.isnan(X1_mask))
N_nans_in_X2_w_multi_gaps_theory = np.sum(np.isnan(X2_mask))
widening_gap_X1_theory = N_nans_in_X1_w_multi_gaps_theory - N_nans_multiple_gaps
widening_gap_X2_theory = N_nans_in_X2_w_multi_gaps_theory - N_nans_multiple_gaps
print("Theory: Number of nans in X1 variables = ", N_nans_in_X1_w_multi_gaps_theory)
print("Theory: Widening of gap in X1 variables = ", widening_gap_X1_theory)
print("Theory: Number of nans in X2 variables = ", N_nans_in_X2_w_multi_gaps_theory)
print("Theory: Widening of gap in X2 variables = ", widening_gap_X2_theory)
print("")
# Can I try to approximate this result?
print("Now using our quick approximation formula")
print("")
approx_nans_in_X1 = approx_total_nans_from_nan_blocks_X(full_mask_3_day, delay_integer_fraction, order=order, generation=1)
approx_nans_in_X2 = approx_total_nans_from_nan_blocks_X(full_mask_3_day, delay_integer_fraction, order=order, generation=2)

approx_N_nans_in_X1_w_multi_gaps_theory = np.sum(np.isnan(X1_mask))
approx_N_nans_in_X2_w_multi_gaps_theory = np.sum(np.isnan(X2_mask))
approx_widening_gap_X1_theory = approx_N_nans_in_X1_w_multi_gaps_theory - N_nans_multiple_gaps
approx_widening_gap_X2_theory = approx_N_nans_in_X2_w_multi_gaps_theory - N_nans_multiple_gaps
print("Approx: Number of nans in X1 variables = ", approx_N_nans_in_X1_w_multi_gaps_theory)
print("Approx:  Widening of gap in X1 variables = ", approx_widening_gap_X1_theory)
print("Approx: Number of nans in X2 variables = ", approx_N_nans_in_X2_w_multi_gaps_theory)
print("Approx:  Widening of gap in X2 variables = ", approx_widening_gap_X2_theory)
# Out:
# Using pytdi
# pytdi: Number of nans in X1 variables =  1980
# pytdi: Widening of gap in X1 variables =  1940
# pytdi: Number of nans in X2 variables =  3540
# pytdi: Widening of gap in X2 variables =  3500
#
# Now doing things carefully but using theory
#
# Theory: Number of nans in X1 variables =  1980
# Theory: Widening of gap in X1 variables =  1940
# Theory: Number of nans in X2 variables =  3540
# Theory: Widening of gap in X2 variables =  3500
#
# Now using our quick approximation formula
#
# Approx: Number of nans in X1 variables =  1980
# Approx:  Widening of gap in X1 variables =  1940
# Approx: Number of nans in X2 variables =  3540
# Approx:  Widening of gap in X2 variables =  3500
