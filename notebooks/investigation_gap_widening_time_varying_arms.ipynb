# %% [markdown]
# # Research Notebook
#
# ## The goal
#
# The goal here is to understand the impact that data gaps have on the L01 pipeline. As seen, the impact of gaps on the telemetry variables result in a widening of the data gaps in the overall Michelson-like variables. I want to try and understand
#
# * What type of data gap is most impacted
# * What generation of TDI is most impactful
# * What do the data gap widening depend on?
# * Can I build a distribution of data gaps?

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import sys
import matplotlib.pyplot as plt
from tqdm import tqdm as tqdm
data_direc = "../data_for_simulations"
sys.path.append("../../artifacts_gen/gaps/")  # if gap_widening_utils.py is in the parent directory
from lisa_gap import GapMaskGenerator

sys.path.append("../utility_funcs")  # if gap_widening_utils.py is in the parent directory
from gap_widening_utils import (
    construct_mask_single_gap,
    gap_augmentation_expression,
    widening_gap_X1,
    widening_gap_X2
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Set up the instrument simulator

# %%
# Set up lolipops pipeline
from pathlib import Path
from lisainstrument import Instrument
from lisaorbits import KeplerianOrbits
from lisaorbits import OEMOrbits


import logging

simlen = 120_000
#simlen = 15 * 120_000 

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logging.getLogger('lisainstrument').setLevel(logging.INFO)

## if keplerian orbit
#orbits = KeplerianOrbits()

## if ESA orbit 

orbits = OEMOrbits.from_included('esa-trailing') #, size=14240)
orbits.write("esa_orbits.h5", t0 = orbits.t_start+10, mode = 'w')

instr_time_varying = Instrument(size=simlen, dt = 0.25, orbits ="esa_orbits.h5" , seed=1234)

instr_time_varying.disable_all_noises(excluding=['laser', 'test-mass', 'oms']) 
instr_time_varying.simulate()

instr_time_varying.write('esa_orbit_short_simulation.h5', mode='w')
# Out:
# 2025-08-13 12:29:04,197 - INFO - Fetching OEM files from ESA repository
# 2025-08-13 12:29:04,206 - INFO - Reading OEM file '/Users/murmar/Library/Caches/lisaorbits/crema_1p0/mida-20deg/trajectory_out_mida-20deg_cw_sg-2nmss.oem1'
# 2025-08-13 12:29:04,706 - INFO - Reading OEM file '/Users/murmar/Library/Caches/lisaorbits/crema_1p0/mida-20deg/trajectory_out_mida-20deg_cw_sg-2nmss.oem2'
# 2025-08-13 12:29:05,201 - INFO - Reading OEM file '/Users/murmar/Library/Caches/lisaorbits/crema_1p0/mida-20deg/trajectory_out_mida-20deg_cw_sg-2nmss.oem3'
# 2025-08-13 12:29:05,700 - WARNING - OEM preferred interpolation method ignored, using spline interpolation (see InterpolatedOrbits for details)
# 2025-08-13 12:29:05,703 - INFO - Initializing orbits (lisaorbit verion 2.4.2)
# 2025-08-13 12:29:05,710 - INFO - Creating orbit file esa_orbits.h5
# 2025-08-13 12:29:05,744 - INFO - Closing orbit file esa_orbits.h5
# 2025-08-13 12:29:05,745 - INFO - Initializing instrumental simulation
# 2025-08-13 12:29:05,749 - INFO - Computing measurement time vector (size=960000, dt=0.25)
# 2025-08-13 12:29:05,752 - INFO - Computing physics time vector (size=3840000, dt=0.0625)
# 2025-08-13 12:29:05,756 - INFO - Computing telemetry time vector (size=4, dt=86400.0)
# 2025-08-13 12:29:05,773 - INFO - Using orbit file 'esa_orbits.h5'
# 2025-08-13 12:29:10,177 - INFO - Using pre-defined locking configuration 'N1-12'
# 2025-08-13 12:29:10,178 - WARNING - Using default set of locking beatnote frequencies; this might cause interferometric beatnote frequencies to fall outside the requirement range of 5..25 MHz
# 2025-08-13 12:29:10,179 - INFO - Designing antialiasing filter ('kaiser', 240, 1.1, 2.9)
# 2025-08-13 12:29:10,180 - INFO - Starting simulation
# 2025-08-13 12:29:10,180 - INFO - Generating clock noise
# 2025-08-13 12:29:10,345 - INFO - Generating modulation noise
# 2025-08-13 12:29:10,346 - INFO - Generating backlink noise
# 2025-08-13 12:29:10,346 - INFO - Generating test-mass acceleration noise
# 2025-08-13 12:29:13,417 - INFO - Generating ranging noise
# 2025-08-13 12:29:13,418 - INFO - Generating OMS noise
# 2025-08-13 12:29:22,620 - INFO - Generating DWS measurement noise
# 2025-08-13 12:29:22,621 - INFO - Generating MOSA longitudinal jitters
# 2025-08-13 12:29:22,621 - INFO - Generating spacecraft angular jitters
# 2025-08-13 12:29:22,622 - INFO - Generating MOSA angular jitters
# 2025-08-13 12:29:22,623 - INFO - Computing MOSA total angular jitters
# 2025-08-13 12:29:22,624 - INFO - Computing tilt-to-length couplings
# 2025-08-13 12:29:23,445 - INFO - Simulating local beams
# 2025-08-13 12:29:23,446 - INFO - Generating laser noise for laser 12
# 2025-08-13 12:29:33,973 - INFO - Propagating local beams to distant MOSAs
# 2025-08-13 12:31:14,527 - INFO - Propagating local beams to adjacent MOSAs
# 2025-08-13 12:31:14,675 - INFO - Propagating local beams to inter-spacecraft interferometers
# 2025-08-13 12:31:14,675 - INFO - Propagating distant beams to inter-spacecraft interferometers
# 2025-08-13 12:31:14,676 - INFO - Computing inter-spacecraft beatnotes on TPS
# 2025-08-13 12:31:15,469 - INFO - Computing inter-spacecraft DWS measurements on TPS
# 2025-08-13 12:31:15,470 - INFO - Computing measured pseudo-ranges on TPS
# 2025-08-13 12:31:15,494 - INFO - Propagating local beams to test-mass interferometers
# 2025-08-13 12:31:15,828 - INFO - Propagating adjacent beams to test-mass interferometers
# 2025-08-13 12:31:15,829 - INFO - Computing test-mass beatnotes on TPS
# 2025-08-13 12:31:16,288 - INFO - Propagating local beams to reference interferometers
# 2025-08-13 12:31:16,288 - INFO - Propagating adjacent beams to reference interferometers
# 2025-08-13 12:31:16,289 - INFO - Computing reference beatnotes on TPS
# 2025-08-13 12:31:16,714 - INFO - Inverting SCET with respect to TPS
# 2025-08-13 12:31:16,734 - INFO - Sampling inter-spacecraft beatnotes to SCET grid
# 2025-08-13 12:31:17,195 - INFO - Sampling measured pseudo-ranges to SCET grid
# 2025-08-13 12:31:17,218 - INFO - Sampling test-mass beatnotes to SCET grid
# 2025-08-13 12:31:17,678 - INFO - Sampling reference beatnotes to SCET grid
# 2025-08-13 12:31:18,193 - INFO - Applying electronic delays
# 2025-08-13 12:31:18,199 - INFO - Filtering beatnotes
# 2025-08-13 12:31:28,030 - INFO - Downsampling beatnotes
# 2025-08-13 12:31:28,034 - INFO - Computing total beatnote frequencies
# 2025-08-13 12:31:28,662 - INFO - Simulation complete
# 2025-08-13 12:31:28,690 - INFO - Writing simulation to 'esa_orbit_short_simulation.h5'
# 2025-08-13 12:31:30,802 - INFO - Closing measurement file 'esa_orbit_short_simulation.h5'

# %%
from pytdi import Data

from pytdi.michelson import compute_factorized_michelson

data = Data.from_instrument(instr_time_varying)
# Out:
# 2025-08-13 12:32:31,124 - INFO - Loading instrument object '<lisainstrument.instrument.Instrument object at 0x1239afb90>'
# 2025-08-13 12:32:31,125 - WARNING - You are using LISA Instrument in a version that might not be fully supported
# 2025-08-13 12:32:31,126 - INFO - Initializing data object
# 2025-08-13 12:32:31,126 - INFO - Computing delay derivatives

# %% [markdown]
# # Widening of the gap due to delays
# ## The $\eta$ variables
#
# Now in the next cell we are going to verify our formula for the widening of the eta variables

# %%
measurement_values = data.MEASUREMENTS
ifos = data.measurements

mprs = data.delays
mpr_derivatives = data.delay_derivatives
MOSAS = data.MOSAS
dt = 1/data.fs

# %%
# I want to trim the mprs values by 1000 points at the start and end
N = 1000
mprs_trimmed = {}
for item in list(mprs.keys()):
    mprs_trimmed[item] = mprs[item][1000:-1000]

# %%
plt.plot(mprs['d_31'][1000:])

# %%
def nanify_telemetry_variables(data, masking_function):
    """
    Apply a masking function (with NaNs) to telemetry variables, pseudo-ranges, and their derivatives.

    Args:
        data (object): Telemetry object with .ifos attribute (dict-like).
        masking_function (np.ndarray): Array of 1s and NaNs to apply as a mask.

    Returns:
        tuple: (telemetry_w_gaps, mprs_w_nans, mpr_derivatives_w_nans)
            telemetry_w_gaps: telemetry object with masked .ifos fields
            mprs_w_nans: dict of masked pseudo-ranges
            mpr_derivatives_w_nans: dict of masked pseudo-range derivatives
        telemetry (object): Telemetry object with .ifos attribute (dict-like).
        mprs (dict): Dictionary of pseudo-range arrays, keyed by MOSA.
        mpr_derivatives (dict): Dictionary of pseudo-range derivative arrays, keyed by MOSA.
        masking_function (np.ndarray): Array of 1s and NaNs to apply as a mask.

    Returns:
        tuple: (telemetry_w_gaps, mprs_w_nans, mpr_derivatives_w_nans)
            telemetry_w_gaps: telemetry object with masked .ifos fields
            mprs_w_nans: dict of masked pseudo-ranges
            mpr_derivatives_w_nans: dict of masked pseudo-range derivatives
    """
    import copy

    # Deep copy to avoid modifying original data
    MOSAS = data.MOSAS
    data_w_gaps = copy.deepcopy(data)

    # Build label lists for all relevant telemetry fields
    tmi_label = [f"tmi_{mosa}" for mosa in MOSAS]
    rfi_label = [f"rfi_{mosa}" for mosa in MOSAS]
    rfi_sb_label = [f"rfi_sb_{mosa}" for mosa in MOSAS]
    isi_label = [f"isi_{mosa}" for mosa in MOSAS]
    isi_sb_label = [f"isi_sb_{mosa}" for mosa in MOSAS]

    # Apply mask to all telemetry fields
    for tmi_item, rfi_item, rfi_sb_item, isi_item, isi_sb_item in zip(
        tmi_label, rfi_label, rfi_sb_label, isi_label, isi_sb_label
    ):
        data_w_gaps.measurements[tmi_item] = data.measurements[tmi_item] * masking_function
        data_w_gaps.measurements[rfi_item] = data.measurements[rfi_item] * masking_function
        data_w_gaps.measurements[rfi_sb_item] = data.measurements[rfi_sb_item] * masking_function
        data_w_gaps.measurements[isi_item] = data.measurements[isi_item] * masking_function
        data_w_gaps.measurements[isi_sb_item] = data.measurements[isi_sb_item] * masking_function

    # Deep copy and mask pseudo-ranges and their derivatives
    for delay_craft in list(data.delays.keys()):
        data_w_gaps.delays[delay_craft] = masking_function * data.delays[delay_craft]
        data_w_gaps.delay_derivatives[delay_craft] = masking_function * data.delay_derivatives[delay_craft]

    return data_w_gaps

# %%
# Construct gap class

CONTROL_NANS = True
GAP_CLASS = False

sim_t = np.arange(0, simlen * dt, dt)


N_tel_nans= 20

masking_function = construct_mask_single_gap(N_tel_nans, length = simlen)


plt.plot(sim_t / 60 / 60 / 24, masking_function)
plt.title("Full gap mask")
plt.xlabel("Time [day]")
plt.ylabel("Gap mask")
plt.grid(True)

print(
    "Lost out on approximately",
    np.sum(np.isnan(masking_function)) * 0.25 / 60 / 60,
    "hours of data",
)
print(
    "This ammounts to {} number of samples".format(np.sum(np.isnan(masking_function)))
)
# Out:
# Lost out on approximately 0.0013888888888888887 hours of data
# This ammounts to 20 number of samples

# %%
from pytdi.intervar import compute_etas

N_nans = 2000
order = 27
masking_function = construct_mask_single_gap(N_nans, length = simlen)
data_w_gaps = nanify_telemetry_variables(data, masking_function)
etas_w_gaps_nans = compute_etas(data_w_gaps, order, unit = "frequency")

N_nans_in_data = np.sum(np.isnan(data_w_gaps.measurements["tmi_12"]))
print("Number of nans in data", N_nans_in_data)
N_nans_in_eta_pytdi = np.sum(np.isnan(etas_w_gaps_nans["eta_12"]))
widening_gap_eta_pytdi = N_nans_in_eta_pytdi - N_nans
print("Number of nans in the eta variables = ", N_nans_in_eta_pytdi)
print("Overall widening of gap in eta variables = ", widening_gap_eta_pytdi)
# Out:
# 2025-08-13 13:53:18,486 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 13:53:18,488 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 13:53:19,193 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 13:53:19,195 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 13:53:19,843 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 13:53:19,845 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 13:53:20,519 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 13:53:20,520 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 13:53:20,982 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 13:53:20,984 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 13:53:21,447 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 13:53:21,449 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# Number of nans in data 2000
# Number of nans in the eta variables =  2046
# Overall widening of gap in eta variables =  46

# %%
# Check formula
from lisaconstants import au, SPEED_OF_LIGHT

# Check formula with analytical computation:
# we can consider three type of delays:

# 1) constant delay equal to the average one which in this case is used to run the simulation

constant_delay1 = np.float64(2.5e9/SPEED_OF_LIGHT)

# 2) constant delay equal to the maximum  value for the entire mission duration 

constant_delay2 = np.float64(2.54E9/SPEED_OF_LIGHT)

# 3)  constant delay equal to the minimum   value for the entire mission duration 

constant_delay3 = np.float64(2.45E9/SPEED_OF_LIGHT)


delay = constant_delay1/dt # Here we take the mean LTT. 

step_size = 0.05

# Build delay array
delay_array = np.arange(constant_delay3, constant_delay2 - 1e-12, step_size)  # decreasing
delay_array_idx = delay_array / dt  # convert to index units if needed


widening_gap_eta_theory, N_nans_in_eta_theory = gap_augmentation_expression(order, N_nans, delay, delay_number=1.0)
print("Number of nans in the eta variables = ", N_nans_in_eta_theory)
print("Overall widening of gap in eta variables = ", widening_gap_eta_theory)
# Out:
# Number of nans in the eta variables =  2047
# Overall widening of gap in eta variables =  47

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 10))

idx_start_gap = np.argwhere(np.isnan(masking_function) == True)[0][0]
idx_end_gap = np.argwhere(np.isnan(masking_function) == True)[-1][-1]
# First subplot: Original plot with gaps and no gaps
j = 1000
axs[0].plot(sim_t, data_w_gaps.measurements["tmi_23"], label="with gaps", alpha=1)
axs[0].plot(sim_t, data.measurements["tmi_23"], label="no gaps", alpha=0.2)
axs[0].set_xlim([sim_t[idx_start_gap] - j, sim_t[idx_start_gap] + j])
axs[0].set_ylabel(r"TMI_23")
# axs[0].set_ylim([-4100, -3200])
axs[0].set_xlabel("Time [s]")
axs[0].legend()
axs[0].set_title("TMI_23 with and without gaps")

# Second subplot: Absolute difference between the two
absolute_difference = np.abs(data_w_gaps.measurements["tmi_23"] - data.measurements["tmi_23"])
axs[1].plot(sim_t, absolute_difference, label="Absolute Difference", color="red")
axs[1].set_xlim([sim_t[idx_start_gap] - j, sim_t[idx_start_gap] + j])
axs[1].set_ylabel("Absolute Difference")
axs[1].set_xlabel("Time [s]")
axs[1].legend()
axs[1].set_title("Absolute Difference between TMI_23 with and without gaps")

plt.tight_layout()
plt.show()

# %%
order = 45
results_testing_N_nans = []
N_nans_in_telem_values = np.logspace(0, 2, num=50, dtype=int)  # Logarithmic spacing from 1 to 10000

for N_nans in tqdm(N_nans_in_telem_values):
    # Construct masking function
    masking_function = construct_mask_single_gap(N_nans, length=simlen)
        
    # Generate telemetry with gaps
    data_w_gaps = nanify_telemetry_variables(data, masking_function)

    # Compute eta variables with gaps
    etas_w_gaps_nans = compute_etas(data_w_gaps, order, unit="frequency")        
    # Calculate N_nans and widening for pytdi
    N_nans_in_eta_pytdi = np.sum(np.isnan(etas_w_gaps_nans["eta_12"]))
    widening_gap_eta_pytdi = N_nans_in_eta_pytdi - N_nans

    # Calculate N_nans and widening for theoretical model
    widening_gap_eta_theory, N_nans_in_eta_theory = gap_augmentation_expression(
        order, N_nans, delay, delay_number=1
    )
        
    # Append results to the list
    results_testing_N_nans.append({
        "N_nans": N_nans,
        "N_nans_in_eta_pytdi": N_nans_in_eta_pytdi,
        "N_nans_in_eta_theory": N_nans_in_eta_theory,
        "widening_gap_eta_pytdi": widening_gap_eta_pytdi,
        "widening_gap_eta_theory": widening_gap_eta_theory
    })
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]2025-08-13 12:34:15,536 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:34:15,539 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:34:17,333 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:34:17,335 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:34:18,762 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:34:18,764 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:34:20,176 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:34:20,179 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:34:21,144 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:34:21,146 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:34:22,085 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:34:22,087 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
#   2%|▏         | 1/50 [00:07<06:21,  7.79s/it]2025-08-13 12:34:23,239 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:34:23,241 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:34:24,660 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:34:24,661 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:34:26,073 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:34:26,074 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:34:27,487 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:34:27,488 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:34:28,460 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:34:28,462 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:34:29,406 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:34:29,408 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
#   4%|▍         | 2/50 [00:15<06:00,  7.50s/it]2025-08-13 12:34:30,472 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:34:30,473 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:34:31,902 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:34:31,904 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:34:33,340 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:34:33,342 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:34:34,805 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:34:34,808 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:34:35,823 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12
- INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:40:02,838 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:40:02,839 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:40:03,983 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:40:03,985 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
#  88%|████████▊ | 44/50 [05:49<00:49,  8.24s/it]2025-08-13 12:40:05,183 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:40:05,189 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:40:06,777 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:40:06,778 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:40:08,372 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:40:08,374 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:40:09,890 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:40:09,892 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:40:10,876 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:40:10,878 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:40:11,928 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:40:11,930 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
#  90%|█████████ | 45/50 [05:57<00:40,  8.15s/it]2025-08-13 12:40:13,089 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:40:13,091 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:40:14,607 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:40:14,609 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:40:16,201 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:40:16,203 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:40:17,814 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:40:17,816 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:40:18,864 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:40:18,866 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:40:19,921 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:40:19,923 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
#  92%|█████████▏| 46/50 [06:05<00:32,  8.10s/it]2025-08-13 12:40:21,093 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:40:21,094 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:40:22,689 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:40:22,691 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:40:24,293 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:40:24,294 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:40:25,896 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:40:25,898 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:40:26,955 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:40:26,957 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:40:27,977 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:40:27,979 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
#  94%|█████████▍| 47/50 [06:13<00:24,  8.10s/it]2025-08-13 12:40:29,170 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:40:29,173 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:40:30,675 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:40:30,677 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:40:32,325 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:40:32,327 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:40:33,959 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:40:33,961 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:40:35,037 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:40:35,039 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:40:36,094 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:40:36,096 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
#  96%|█████████▌| 48/50 [06:21<00:16,  8.09s/it]2025-08-13 12:40:37,244 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:40:37,247 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:40:38,862 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:40:38,864 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:40:40,432 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:40:40,433 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:40:42,030 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:40:42,031 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:40:43,067 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:40:43,069 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:40:44,151 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:40:44,153 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
#  98%|█████████▊| 49/50 [06:29<00:08,  8.08s/it]2025-08-13 12:40:45,342 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:40:45,346 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:40:46,906 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:40:46,908 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:40:48,491 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:40:48,494 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:40:50,042 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:40:50,044 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:40:51,085 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:40:51,087 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:40:52,110 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:40:52,111 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 100%|██████████| 50/50 [06:37<00:00,  7.96s/it]

# %%
# Plot the results of the above cell

import matplotlib.pyplot as plt
import numpy as np

# Extract data from results
N_nans_in_telem_values = [result["N_nans"] for result in results_testing_N_nans]
widening_gap_eta_pytdi = [result["widening_gap_eta_pytdi"] for result in results_testing_N_nans]
widening_gap_eta_theory = [result["widening_gap_eta_theory"] for result in results_testing_N_nans]

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(N_nans_in_telem_values, widening_gap_eta_pytdi, label="pytdi", marker="o", linestyle="-", color="blue")
plt.plot(N_nans_in_telem_values, widening_gap_eta_theory, label="Prediction", marker="s", linestyle="--", color="orange", alpha = 0.7)

# Add labels, legend, and grid
plt.xscale("log")
plt.xlabel("Number of NaNs in telemetry", fontsize=20)
plt.ylabel(r"Widening of Gap in $\eta$ variables", fontsize=20)
plt.title("Comparison of Gap Widening: pytdi vs Prediction", fontsize=20)
plt.legend(fontsize=26)

# Increase tick sizes
plt.tick_params(axis="both", which="major", labelsize=16)

plt.grid(True, which="both", linestyle="--", linewidth=0.5)

# Save and show the plot
plt.tight_layout()
# plt.savefig("../Plots/gap_widening_comparison.png", dpi=300)  # Save as a high-resolution image
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

order = 45

N_nans_in_telem_values = np.logspace(0, 1.3, num=50, dtype=int)  # Logarithmic spacing from 1 to 10000

# Delay values
constant_delay2 = np.float64(2.48E9 / SPEED_OF_LIGHT)
constant_delay3 = np.float64(2.47E9 / SPEED_OF_LIGHT)
step_size = 0.01

delay_array = np.arange(constant_delay2, constant_delay3 - 1e-12, -step_size)
delay_array_idx = delay_array / dt


# Plot setup
plt.figure(figsize=(8, 6))

for delay_val, delay_idx in zip(delay_array, delay_array_idx):
    widenings_for_delay = []
    T_nans_for_delay = []

    for N_nans_in_telem in N_nans_in_telem_values:
        widening, T_nans = gap_augmentation_expression(
            order, N_nans_in_telem, delay_idx, delay_number=1
        )
        widenings_for_delay.append(widening)
        T_nans_for_delay.append(T_nans)

    # Plot one curve per delay
    plt.plot(N_nans_in_telem_values, widenings_for_delay, marker='o', label=f"Delay={delay_val / dt:.2f} s")

# Add labels, legend, and grid

plt.xlabel("Number of NaNs in telemetry", fontsize=20)
plt.ylabel(r"Widening of Gap in $\eta$ variables", fontsize=20)

plt.legend(fontsize=15)

# Increase tick sizes
plt.tick_params(axis="both", which="major", labelsize=16)

plt.grid(True, which="both", linestyle="--", linewidth=0.5)

# %% [markdown]
# # What do we learn here?
# ## For large strings of missing data, gap augmentation is constant.

# %%
results_by_order = {}

# Define the gap configurations and range of orders
gap_configurations = [1, 10, 100]
orders = range(25, 81,2)  # From 25 to 81 inclusive

# Loop over each gap configuration
for N_nans in gap_configurations:
    results_by_order[N_nans] = []  # Initialize results for this gap configuration
    
    # Construct masking function
    masking_function = construct_mask_single_gap(N_nans, length=simlen) 
    # Generate telemetry with gaps
    data_w_gaps = nanify_telemetry_variables(data, masking_function)
    for order in tqdm(orders):
        
        # Compute eta variables with gaps
        etas_w_gaps_nans = compute_etas(data_w_gaps, order, unit="frequency")        
        # Calculate N_nans and widening for pytdi
        N_nans_in_eta_pytdi = np.sum(np.isnan(etas_w_gaps_nans["eta_12"]))
        widening_gap_eta_pytdi = N_nans_in_eta_pytdi - N_nans

        # Calculate N_nans and widening for theoretical model
        widening_gap_eta_theory, N_nans_in_eta_theory = gap_augmentation_expression(
            order, N_nans, delay, delay_number=1
        )
        
        # Append results to the list for this gap configuration
        results_by_order[N_nans].append({
            "order": order,
            "N_nans_in_eta_pytdi": N_nans_in_eta_pytdi,
            "N_nans_in_eta_theory": N_nans_in_eta_theory,
            "widening_gap_eta_pytdi": widening_gap_eta_pytdi,
            "widening_gap_eta_theory": widening_gap_eta_theory
        })
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]2025-08-13 12:42:32,033 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:42:32,035 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:42:32,799 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:42:32,801 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:42:33,402 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:42:33,404 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:42:33,983 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:42:33,985 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:42:34,377 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:42:34,379 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:42:34,770 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:42:34,771 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
#   4%|▎         | 1/28 [00:03<01:24,  3.13s/it]2025-08-13 12:42:35,166 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:42:35,167 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:42:35,819 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:42:35,821 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:42:36,498 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:42:36,500 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:42:37,171 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:42:37,173 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:42:37,632 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:42:37,634 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:42:38,088 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:42:38,089 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
#   7%|▋         | 2/28 [00:06<01:24,  3.27s/it]2025-08-13 12:42:38,527 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:42:38,528 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:42:39,270 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:42:39,272 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:42:40,048 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:42:40,050 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:42:40,805 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:42:40,807 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:42:41,303 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:42:41,305 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:42:41,834 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:42:41,835 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
#  11%|█         | 3/28 [00:10<01:27,  3.52s/it]2025-08-13 12:42:42,345 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:42:42,346 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:42:43,201 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:42:43,202 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:42:44,031 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:42:44,033 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:42:44,863 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:42
- INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:55:50,446 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:55:53,279 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:55:53,280 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:55:56,100 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:55:56,102 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:55:58,964 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:55:58,966 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:56:00,857 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:56:00,858 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:56:02,762 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:56:02,764 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
#  79%|███████▊  | 22/28 [02:52<01:14, 12.38s/it]2025-08-13 12:56:04,624 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:56:04,625 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:56:08,450 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:56:08,452 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:56:12,230 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:56:12,232 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:56:16,059 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:56:16,060 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:56:18,609 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:56:18,610 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:56:21,114 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:56:21,116 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
#  82%|████████▏ | 23/28 [03:11<01:11, 14.38s/it]2025-08-13 12:56:23,651 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:56:23,653 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:56:27,639 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:56:27,641 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:56:31,620 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:56:31,622 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:56:35,584 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:56:35,585 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:56:38,230 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:56:38,231 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:56:40,880 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:56:40,882 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
#  86%|████████▌ | 24/28 [03:31<01:04, 16.02s/it]2025-08-13 12:56:43,509 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:56:43,510 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:56:47,652 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:56:47,654 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:56:51,785 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:56:51,787 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:56:55,936 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:56:55,938 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:56:58,664 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:56:58,666 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:57:01,482 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:57:01,484 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
#  89%|████████▉ | 25/28 [03:51<00:52, 17.42s/it]2025-08-13 12:57:04,187 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:57:04,189 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:57:08,476 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:57:08,478 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:57:12,730 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:57:12,731 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:57:17,025 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:57:17,027 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:57:19,896 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:57:19,897 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:57:22,755 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:57:22,757 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
#  93%|█████████▎| 26/28 [04:13<00:37, 18.62s/it]2025-08-13 12:57:25,598 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:57:25,600 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:57:30,090 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:57:30,091 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:57:34,572 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:57:34,574 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:57:39,029 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:57:39,031 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:57:42,024 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:57:42,026 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:57:44,992 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:57:44,994 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
#  96%|█████████▋| 27/28 [04:35<00:19, 19.73s/it]2025-08-13 12:57:47,943 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:57:47,944 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:57:52,581 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:57:52,582 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:57:57,223 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:57:57,225 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:58:02,015 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:58:02,017 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:58:05,228 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:58:05,230 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:58:08,434 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:58:08,436 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 100%|██████████| 28/28 [04:59<00:00, 10.69s/it]

# %%
import matplotlib.pyplot as plt
plt.clf()
# Create a single plot for all gap configurations
plt.figure(figsize=(12, 8))

# Define markers and colors for each gap configuration
markers = ["o", "s", "D"]
colors = ["blue", "orange", "green"]

# Loop through each gap configuration and plot the results
for idx, (N_nans, results) in enumerate(results_by_order.items()):
    # Extract data for this N_nans configuration
    orders = [result["order"] for result in results]
    widening_gap_eta_pytdi = [result["widening_gap_eta_pytdi"] for result in results]
    widening_gap_eta_theory = [result["widening_gap_eta_theory"] for result in results]

    # Plot pytdi results (solid lines)
    plt.plot(
        orders, widening_gap_eta_pytdi,
        label=f"PyTDI (N_nans={N_nans})", 
        linestyle="-", color=colors[idx], zorder=1
    )
    
    # Plot theoretical results (dashed lines)
    plt.plot(
        orders, widening_gap_eta_theory, 
        label=f"Prediction (N_nans={N_nans})", 
        marker=markers[idx], color=colors[idx], zorder=2
    )

# Add labels, legend, and grid
plt.xlabel("Order of Interpolant", fontsize=20)
plt.ylabel(r"Widening of Gap in $\eta$ Variables", fontsize=20)
plt.title("Comparison of Gap Widening: Lolipops vs Theory", fontsize=20)
plt.legend(fontsize=12, loc="upper left")
plt.grid(True, linestyle="--", linewidth=0.5)

# Increase tick sizes
plt.tick_params(axis="both", which="major", labelsize=16)

# Save and show the plot
plt.tight_layout()
# plt.savefig("../Plots/gap_widening_comparison_all_configs.png", dpi=300)  # Save as a high-resolution image
plt.show()

# %% [markdown]
# # Now let's try to do the same thing but with factorized variables
#
# We have no shown that the widening of the gap in the $\eta$ variables is sensitive to three things:
#
# * The number of consecutive missing data in the telemetry variables
# * The integer delay used when computing the interpolation
# * The order of the interpolant.
#
# However, the quantity that L2A and L2D are most interested in are the L1 data products. In other words, the laser-cleaned TDI combinations $X$, $Y$ and $Z$ for various generations of TDI. Below we will do a similar analysis but now considering the TDI variables.

# %%
from tqdm import tqdm as tqdm
order = 45
results_TDI_testing_N_nans = []

N_nans_in_telem_values = np.logspace(0, 2, num=50, dtype=int)  # Logarithmic spacing from 1 to 10000

for N_nans in tqdm(N_nans_in_telem_values):
    # Construct masking function
    masking_function = construct_mask_single_gap(N_nans, length=simlen)
        
    # Generate telemetry with gaps
    data_w_gaps = nanify_telemetry_variables(
        data, masking_function
    )
        
    # Compute eta variables with gaps
    etas_w_gaps_nans = compute_etas(
        data_w_gaps, order = 45, unit = "frequency"
    )
    TDI_X = []
    for gen in range(1,3):
        # rot = 0 stands for TDI X variable 
        result = compute_factorized_michelson(
            data_w_gaps, etas = etas_w_gaps_nans, rot = 0, order = order, generation = gen
    )
        TDI_X.append(result)
        
    # Calculate N_nans and widening for lolipops
    N_nans_in_TDI = [np.sum(np.isnan(TDI_X[i])) for i in range(len(TDI_X))]
    N_nans_in_X1_pytdi = N_nans_in_TDI[0] 
    N_nans_in_X2_pytdi = N_nans_in_TDI[1] 

    widening_gap_X1_pytdi = N_nans_in_X1_pytdi - N_nans
    widening_gap_X2_pytdi = N_nans_in_X2_pytdi - N_nans
        
    # Calculate N_nans and widening for theoretical model
    _, N_nans_in_X1_theory = widening_gap_X1(order, N_nans, delay)
    _, N_nans_in_X2_theory = widening_gap_X2(order, N_nans, delay)

    widening_gap_X1_theory = N_nans_in_X1_theory - N_nans
    widening_gap_X2_theory = N_nans_in_X2_theory - N_nans
        
    # Append results to the list
    results_TDI_testing_N_nans.append({
        "N_nans": N_nans,
        "N_nans_in_X1_pytdi": N_nans_in_X1_pytdi,
        "N_nans_in_X2_pytdi": N_nans_in_X2_pytdi,
        "widening_gap_X1_pytdi": widening_gap_X1_pytdi,
        "widening_gap_X2_pytdi": widening_gap_X2_pytdi,
        "N_nans_in_X1_theory": N_nans_in_X1_theory,
        "N_nans_in_X2_theory": N_nans_in_X2_theory,
        "widening_gap_X1_theory": widening_gap_X1_theory,
        "widening_gap_X2_theory": widening_gap_X2_theory
    })
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]2025-08-13 12:58:12,051 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:58:12,053 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 12:58:13,575 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:58:13,577 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 12:58:15,028 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:58:15,030 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 12:58:16,482 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:58:16,484 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 12:58:17,435 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:58:17,437 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 12:58:18,384 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:58:18,385 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 12:58:19,360 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-08-13 12:58:19,361 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x124500ce0>'
# 2025-08-13 12:58:19,362 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x124500ce0>'
# 2025-08-13 12:58:19,849 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-08-13 12:58:19,850 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x
- INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1245d7c20>'
# 2025-08-13 13:08:40,290 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1245d7c20>'
# 2025-08-13 13:08:40,765 - INFO - Initializing combination with components '{'x_arm_1': [(-1, []), (1, ['D_13', 'D_31'])], 'x_arm_2': [(1, []), (-1, ['D_12', 'D_21'])]}'
# 2025-08-13 13:08:40,766 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1245d7c20>'
# 2025-08-13 13:08:40,929 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1245d7c20>'
# 2025-08-13 13:08:41,880 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-08-13 13:08:41,881 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x12416edb0>'
# 2025-08-13 13:08:41,883 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x12416edb0>'
# 2025-08-13 13:08:42,360 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-08-13 13:08:42,361 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x124627c50>'
# 2025-08-13 13:08:42,362 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x124627c50>'
# 2025-08-13 13:08:42,844 - INFO - Initializing combination with components '{'arm_a': [(1, [])], 'arm_b': [(1, ['D_12', 'D_21'])]}'
# 2025-08-13 13:08:42,844 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1246447a0>'
# 2025-08-13 13:08:42,927 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1246447a0>'
# 2025-08-13 13:08:43,400 - INFO - Initializing combination with components '{'arm_a': [(1, ['D_13', 'D_31'])], 'arm_b': [(1, [])]}'
# 2025-08-13 13:08:43,400 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x12448ba10>'
# 2025-08-13 13:08:43,482 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x12448ba10>'
# 2025-08-13 13:08:43,951 - INFO - Initializing combination with components '{'roundtrip_a': [(-1, []), (1, ['D_13', 'D_31', 'D_12', 'D_21'])], 'roundtrip_b': [(1, []), (-1, ['D_12', 'D_21', 'D_13', 'D_31'])]}'
# 2025-08-13 13:08:43,952 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x124583c20>'
# 2025-08-13 13:08:44,431 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x124583c20>'
#  98%|█████████▊| 49/50 [10:33<00:12, 12.89s/it]2025-08-13 13:08:45,440 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 13:08:45,441 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 13:08:46,859 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 13:08:46,861 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 13:08:48,315 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 13:08:48,317 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 13:08:49,751 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 13:08:49,752 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 13:08:50,701 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 13:08:50,702 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 13:08:51,653 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 13:08:51,654 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 13:08:52,602 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-08-13 13:08:52,603 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x12451d9a0>'
# 2025-08-13 13:08:52,604 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x12451d9a0>'
# 2025-08-13 13:08:53,084 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-08-13 13:08:53,085 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x12451d9a0>'
# 2025-08-13 13:08:53,086 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x12451d9a0>'
# 2025-08-13 13:08:53,561 - INFO - Initializing combination with components '{'x_arm_1': [(-1, []), (1, ['D_13', 'D_31'])], 'x_arm_2': [(1, []), (-1, ['D_12', 'D_21'])]}'
# 2025-08-13 13:08:53,562 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x12451d9a0>'
# 2025-08-13 13:08:53,729 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x12451d9a0>'
# 2025-08-13 13:08:54,673 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-08-13 13:08:54,673 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1243cdfa0>'
# 2025-08-13 13:08:54,675 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1243cdfa0>'
# 2025-08-13 13:08:55,150 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-08-13 13:08:55,150 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1243cd2b0>'
# 2025-08-13 13:08:55,152 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1243cd2b0>'
# 2025-08-13 13:08:55,625 - INFO - Initializing combination with components '{'arm_a': [(1, [])], 'arm_b': [(1, ['D_12', 'D_21'])]}'
# 2025-08-13 13:08:55,626 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x12446efc0>'
# 2025-08-13 13:08:55,708 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x12446efc0>'
# 2025-08-13 13:08:56,186 - INFO - Initializing combination with components '{'arm_a': [(1, ['D_13', 'D_31'])], 'arm_b': [(1, [])]}'
# 2025-08-13 13:08:56,187 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1245d7200>'
# 2025-08-13 13:08:56,270 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1245d7200>'
# 2025-08-13 13:08:56,744 - INFO - Initializing combination with components '{'roundtrip_a': [(-1, []), (1, ['D_13', 'D_31', 'D_12', 'D_21'])], 'roundtrip_b': [(1, []), (-1, ['D_12', 'D_21', 'D_13', 'D_31'])]}'
# 2025-08-13 13:08:56,745 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x124147020>'
# 2025-08-13 13:08:57,222 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x124147020>'
# 100%|██████████| 50/50 [10:46<00:00, 12.92s/it]

# %% [markdown]
# # Plot the result
#
# What we will show here is that the gap widening in the TDI variables is weakly dependent on the duration of the gap. We have a similar plot for the eta variables above.

# %%
import matplotlib.pyplot as plt

# Extract data from results
N_nans_values = [result["N_nans"] for result in results_TDI_testing_N_nans]
widening_gap_X1_pytdi = [result["widening_gap_X1_pytdi"] for result in results_TDI_testing_N_nans]
widening_gap_X2_pytdi = [result["widening_gap_X2_pytdi"] for result in results_TDI_testing_N_nans]
widening_gap_X1_theory = [result["widening_gap_X1_theory"] for result in results_TDI_testing_N_nans]
widening_gap_X2_theory = [result["widening_gap_X2_theory"] for result in results_TDI_testing_N_nans]

# Create the figure and subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot X1 results on the left subplot
ax1.plot(
    N_nans_values, widening_gap_X1_pytdi, 
    label="PyTDI (X1)", linestyle="-", color="magenta"
)
ax1.plot(
    N_nans_values, widening_gap_X1_theory, 
    label="Theory (X1)", linestyle="--", marker="o", color="blue"
)
ax1.set_xscale("log")
ax1.set_xlabel("Number of NaNs in telemetry", fontsize=14)
ax1.set_ylabel("Gap Augmentation", fontsize=14)
ax1.set_title("Gap Widening: X1 Variables", fontsize=16)
ax1.legend(fontsize=16, loc="upper left")
ax1.grid(True, which="both", linestyle="--", linewidth=0.5)
ax1.tick_params(axis="both", which="major", labelsize=12)

# Plot X2 results on the right subplot
ax2.plot(
    N_nans_values, widening_gap_X2_pytdi, 
    label="PyTDI (X2)", linestyle="-", color="black"
)
ax2.plot(
    N_nans_values, widening_gap_X2_theory, 
    label="Theory (X2)", linestyle="--", marker="s", color="green"
)
ax2.set_xscale("log")
ax2.set_xlabel("Number of NaNs in telemetry", fontsize=14)
# ax2.set_ylabel("Widening of Gap in X2 Variables", fontsize=14)
ax2.set_title("Gap Widening: X2 Variables", fontsize=16)
ax2.legend(fontsize=16, loc="upper left")
ax2.grid(True, which="both", linestyle="--", linewidth=0.5)
ax2.tick_params(axis="both", which="major", labelsize=16)

# Adjust layout and show the plot
plt.tight_layout()
# plt.savefig("../Plots/gap_widening_comparison_TDI_subplots.png", dpi=300)  # Save as a high-resolution image
plt.show()

# %%
# Plot the results in seconds
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt

# Extract data from results
N_nans_values = [dt*result["N_nans"] for result in results_TDI_testing_N_nans]
widening_gap_X1_pytdi = [dt*result["widening_gap_X1_pytdi"] for result in results_TDI_testing_N_nans]
widening_gap_X2_pytdi = [dt*result["widening_gap_X2_pytdi"] for result in results_TDI_testing_N_nans]
widening_gap_X1_theory = [dt*result["widening_gap_X1_theory"] for result in results_TDI_testing_N_nans]
widening_gap_X2_theory = [dt*result["widening_gap_X2_theory"] for result in results_TDI_testing_N_nans]

# Create the figure and subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot X1 results on the left subplot
ax1.plot(
    N_nans_values, widening_gap_X1_pytdi, 
    label="PyTDI (X1)", linestyle="-", color="magenta"
)
ax1.plot(
    N_nans_values, widening_gap_X1_theory, 
    label="Theory (X1)", linestyle="--", marker="o", color="blue"
)
ax1.set_xscale("log")
ax1.set_xlabel("Gap duration in telemetry [s]", fontsize=14)
ax1.set_ylabel("Gap Augmentation [s]", fontsize=14)
ax1.set_title("Gap Widening: X1 Variables", fontsize=16)
ax1.legend(fontsize=16, loc="upper left")
ax1.grid(True, which="both", linestyle="--", linewidth=0.5)
ax1.tick_params(axis="both", which="major", labelsize=12)

# Plot X2 results on the right subplot
ax2.plot(
    N_nans_values, widening_gap_X2_pytdi, 
    label="PyTDI (X2)", linestyle="-", color="black"
)
ax2.plot(
    N_nans_values, widening_gap_X2_theory, 
    label="Theory (X2)", linestyle="--", marker="s", color="green"
)
ax2.set_xscale("log")
ax2.set_xlabel("Gap duration in telemetry [s]", fontsize=14)
# ax2.set_ylabel("Widening of Gap in X2 Variables", fontsize=14)
ax2.set_title("Gap Widening: X2 Variables", fontsize=16)
ax2.legend(fontsize=16, loc="upper left")
ax2.grid(True, which="both", linestyle="--", linewidth=0.5)
ax2.tick_params(axis="both", which="major", labelsize=16)

# Adjust layout and show the plot
plt.tight_layout()
# plt.savefig("../Plots/gap_widening_comparison_TDI_subplots.png", dpi=300)  # Save as a high-resolution image
plt.show()

# %%
# Create the figure and subplots
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

# Plot X2 results on the left subplot
ax.plot(
    N_nans_values, widening_gap_X2_pytdi, 
    label="PyTDI (X1)", linestyle="-", color="magenta"
)
ax.plot(
    N_nans_values, widening_gap_X2_theory, 
    label="Theory (X1)", linestyle="--", marker="o", color="blue"
)
ax.set_xscale("log")
ax.set_xlabel("Gap duration in telemetry [s]", fontsize=14)
ax.set_ylabel("Gap Augmentation [s]", fontsize=14)
ax.set_title("Gap Widening: X1 Variables", fontsize=16)
ax.legend(fontsize=16, loc="upper left")
ax.grid(True, which="both", linestyle="--", linewidth=0.5)
ax.tick_params(axis="both", which="major", labelsize=12)

# %%
TDI_results_by_order = {}

# Define the gap configurations and range of orders
gap_configurations = [1, 10, 25]
orders = range(25, 81, 2)  # From 25 to 81 inclusive

# Loop over each gap configuration
for N_nans in gap_configurations:
    TDI_results_by_order[N_nans] = []  # Initialize results for this gap configuration
    # Construct masking function
    masking_function = construct_mask_single_gap(N_nans, length=simlen)
    
    for order in tqdm(orders):
        
        # Generate telemetry with gaps
        data_w_gaps = nanify_telemetry_variables(
            data, masking_function
        )
        
        # Compute eta variables with gaps
        etas_w_gaps_nans = compute_etas(
            data_w_gaps, order, unit="frequency"
        )        
        # Compute TDI variables for two generations
        TDI_X = []
        for gen in range(1, 3):
            result = compute_factorized_michelson(
                data_w_gaps, etas=etas_w_gaps_nans, rot=0, order=order, generation=gen
            )
            TDI_X.append(result)
        
        # Calculate N_nans and widening for pytdi
        N_nans_in_TDI = [np.sum(np.isnan(TDI_X[i])) for i in range(len(TDI_X))]
        widening_gap_X1_pytdi = N_nans_in_TDI[0] - N_nans
        widening_gap_X2_pytdi = N_nans_in_TDI[1] - N_nans

        # Calculate N_nans and widening for theoretical model
        _, N_nans_in_X1_theory = widening_gap_X1(order, N_nans, delay)
        _, N_nans_in_X2_theory = widening_gap_X2(order, N_nans, delay)
        widening_gap_X1_theory = N_nans_in_X1_theory - N_nans
        widening_gap_X2_theory = N_nans_in_X2_theory - N_nans
        
        # Append results to the list for this gap configuration
        TDI_results_by_order[N_nans].append({
            "order": order,
            "widening_gap_X1_pytdi": widening_gap_X1_pytdi,
            "widening_gap_X2_pytdi": widening_gap_X2_pytdi,
            "widening_gap_X1_theory": widening_gap_X1_theory,
            "widening_gap_X2_theory": widening_gap_X2_theory,
        })
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]2025-08-13 13:09:00,362 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 13:09:00,363 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 13:09:01,026 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 13:09:01,028 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 13:09:01,589 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 13:09:01,590 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 13:09:02,152 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 13:09:02,154 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 13:09:02,537 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 13:09:02,538 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 13:09:02,921 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 13:09:02,922 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 13:09:03,320 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-08-13 13:09:03,320 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x124768d40>'
# 2025-08-13 13:09:03,322 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x124768d40>'
# 2025-08-13 13:09:03,510 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-08-13 13:09:03,511 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1249f33b0>'
# 2025-08-13 13:09:03,512 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1249f33b0>'
# 2025-08-13 13:09:03,700 - INFO - Initializing combination with components '{'x_arm_1': [(-1, []), (1, ['D_13', 'D_31'])], 'x_arm_2': [(1, []), (-1, ['D_12', 'D_21'])]}'
# 2025-08-13 13:09:03,701 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x124768d40>'
# 2025-08-13 13:09:03,895 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x124768d40>'
# 2025-08-13 13:09:04,283 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-08-13 13:09:04,283 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1247cc3e0>'
# 2025-08-13 13:09:04,285 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1247cc3e0>'
# 2025-08-13 13:09:04,472 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-08-13 13:09:04,473 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1248954c0>'
# 2025-08-13 13:09:04,474 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x
- INFO - Building combination '<pytdi.core.LISATDICombination object at 0x124581f70>'
# 2025-08-13 13:36:54,366 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x124581f70>'
#  96%|█████████▋| 27/28 [10:33<00:34, 34.89s/it]2025-08-13 13:36:57,386 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 13:36:57,388 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209cf500>'
# 2025-08-13 13:37:02,031 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 13:37:02,033 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a05f10>'
# 2025-08-13 13:37:06,752 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 13:37:06,754 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x120a22f90>'
# 2025-08-13 13:37:11,529 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 13:37:11,531 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f38f0>'
# 2025-08-13 13:37:14,681 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 13:37:14,682 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x1209f3ce0>'
# 2025-08-13 13:37:17,845 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 13:37:17,847 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x11dc8bbf0>'
# 2025-08-13 13:37:20,980 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-08-13 13:37:20,981 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x124862960>'
# 2025-08-13 13:37:20,983 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x124862960>'
# 2025-08-13 13:37:22,593 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-08-13 13:37:22,594 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x12460ef60>'
# 2025-08-13 13:37:22,595 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x12460ef60>'
# 2025-08-13 13:37:24,201 - INFO - Initializing combination with components '{'x_arm_1': [(-1, []), (1, ['D_13', 'D_31'])], 'x_arm_2': [(1, []), (-1, ['D_12', 'D_21'])]}'
# 2025-08-13 13:37:24,202 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x12460ef60>'
# 2025-08-13 13:37:24,365 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x12460ef60>'
# 2025-08-13 13:37:27,536 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-08-13 13:37:27,537 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x124691940>'
# 2025-08-13 13:37:27,538 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x124691940>'
# 2025-08-13 13:37:29,138 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-08-13 13:37:29,139 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x124691940>'
# 2025-08-13 13:37:29,141 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x124691940>'
# 2025-08-13 13:37:30,757 - INFO - Initializing combination with components '{'arm_a': [(1, [])], 'arm_b': [(1, ['D_12', 'D_21'])]}'
# 2025-08-13 13:37:30,758 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x124691550>'
# 2025-08-13 13:37:30,845 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x124691550>'
# 2025-08-13 13:37:32,451 - INFO - Initializing combination with components '{'arm_a': [(1, ['D_13', 'D_31'])], 'arm_b': [(1, [])]}'
# 2025-08-13 13:37:32,452 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x12478ef60>'
# 2025-08-13 13:37:32,535 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x12478ef60>'
# 2025-08-13 13:37:34,137 - INFO - Initializing combination with components '{'roundtrip_a': [(-1, []), (1, ['D_13', 'D_31', 'D_12', 'D_21'])], 'roundtrip_b': [(1, []), (-1, ['D_12', 'D_21', 'D_13', 'D_31'])]}'
# 2025-08-13 13:37:34,138 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x124710c20>'
# 2025-08-13 13:37:34,626 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x124710c20>'
# 100%|██████████| 28/28 [11:14<00:00, 24.07s/it]

# %%
import matplotlib.pyplot as plt
plt.clf()

# Create the figure and subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Define markers and colors for each gap configuration
markers = ["o", "s", "D"]
colors = ["blue", "orange", "green"]

# Loop through each gap configuration and plot the results for X1
for idx, (N_nans, results) in enumerate(TDI_results_by_order.items()):
    # Extract data for this N_nans configuration
    orders = [result["order"] for result in results]
    widening_gap_X1_pytdi = [result["widening_gap_X1_pytdi"] for result in results]
    widening_gap_X1_theory = [result["widening_gap_X1_theory"] for result in results]
    
    # Plot X1 results on the left subplot
    ax1.plot(
        orders, widening_gap_X1_pytdi, 
        label=f"pytdi X1 nans={N_nans}", 
        linestyle="-", color=colors[idx], zorder=1
    )
    ax1.plot(
        orders, widening_gap_X1_theory, 
        label=f"Prediction X1 nans={N_nans}", 
        marker=markers[idx], linestyle="--", color=colors[idx], zorder=2
    )

# Customize the left subplot (X1)
ax1.set_xlabel("Order of Interpolant", fontsize=25)
ax1.set_ylabel(r"Gap Augmentation", fontsize=25)
# ax1.set_title(r"Gap Widening: $X_1$ Variables", fontsize=20)
ax1.legend(fontsize=16, loc="upper left")
ax1.grid(True, linestyle="--", linewidth=0.5)
ax1.tick_params(axis="both", which="major", labelsize=16)

# Loop through each gap configuration and plot the results for X2
for idx, (N_nans, results) in enumerate(TDI_results_by_order.items()):
    # Extract data for this N_nans configuration
    orders = [result["order"] for result in results]
    widening_gap_X2_pytdi = [result["widening_gap_X2_pytdi"] for result in results]
    widening_gap_X2_theory = [result["widening_gap_X2_theory"] for result in results]
    
    # Plot X2 results on the right subplot
    ax2.plot(
        orders, widening_gap_X2_pytdi, 
        label=f"pytdi X2 nans={N_nans}", 
        linestyle="-", color=colors[idx], zorder=1, alpha=0.7
    )
    ax2.plot(
        orders, widening_gap_X2_theory, 
        label=f"Prediction X2 nans={N_nans}", 
        marker=markers[idx], linestyle="--", color=colors[idx], zorder=2, alpha=0.7
    )

# Customize the right subplot (X2)
ax2.set_xlabel("Order of Interpolant", fontsize=20)
# ax2.set_title(r"Gap Widening: $X_2$ Variables", fontsize=20)
ax2.legend(fontsize=16, loc="upper left")
ax2.grid(True, linestyle="--", linewidth=0.5)
ax2.tick_params(axis="both", which="major", labelsize=16)

# Adjust layout and show the plot
plt.tight_layout()
# plt.savefig("../Plots/gap_widening_comparison_TDI_subplots_change_gap_duration.png", dpi=300)  # Save as a high-resolution image
plt.show()

# %% [markdown]
# # The formulas check out
#
# The formulas work extremely well for standard orders of interpolants $\mathcal{O}(L) \gtrsim 25$ providing that the missing data is contiguous. In other words, the \texttt{nans} are next to eachother. The formula *will* break down if you have multiple gaps that are very close to eachother. This is because as the nans propagate through the pipeline, the gated segments will start eating onto eachother. This means that the formula, predicting the total number of lost data will always over-estimate the loss, rather than underestimate it. This is good, we are being conservative.
#
# ## The future goals
#
# We will have multiple gaps of various durations. The question is how accurately (and quickly) can I predict the overall gap augmentation due to the TDI pipeline? Now I will use a generic masking function to do this.

# %%
# Import the necessary functions from the multi_gap_utils module
# Assuming the functions are defined in a file named multi_gap_utils.py in the same directory
sys.path.append("..")  # if multi_gap_utils.py is in the parent directory
from utility_funcs.multi_gap_utils import (
    mask_eta, 
    mask_TDI_X,
    approx_total_nans_from_nan_blocks_eta,
    approx_total_nans_from_nan_blocks_X
)

# %%
# Consider now a longer simulation 

simlen_multi_gap = 1_050_000

instr_3_days_static = Instrument(size=simlen_multi_gap, dt = 0.25, orbits = 'static_orbits.h5', seed=1234)

instr_3_days_static.disable_all_noises(excluding=['laser', 'test-mass', 'oms']) 
instr_3_days_static.simulate()

instr_3_days_static.write('static_3_day_simulation.h5', mode='w')
# Out:
# 2025-07-16 11:41:06,589 - INFO - Initializing instrumental simulation
# 2025-07-16 11:41:06,607 - INFO - Computing measurement time vector (size=1050000, dt=0.25)
# 2025-07-16 11:41:06,609 - INFO - Computing physics time vector (size=4200000, dt=0.0625)
# 2025-07-16 11:41:06,616 - INFO - Computing telemetry time vector (size=5, dt=86400.0)
# 2025-07-16 11:41:06,630 - INFO - Using orbit file 'static_orbits.h5'
# 2025-07-16 11:41:09,227 - INFO - Using pre-defined locking configuration 'N1-12'
# 2025-07-16 11:41:09,227 - WARNING - Using default set of locking beatnote frequencies; this might cause interferometric beatnote frequencies to fall outside the requirement range of 5..25 MHz
# 2025-07-16 11:41:09,227 - INFO - Designing antialiasing filter ('kaiser', 240, 1.1, 2.9)
# 2025-07-16 11:41:09,228 - INFO - Starting simulation
# 2025-07-16 11:41:09,228 - INFO - Generating clock noise
# 2025-07-16 11:41:09,302 - INFO - Generating modulation noise
# 2025-07-16 11:41:09,302 - INFO - Generating backlink noise
# 2025-07-16 11:41:09,303 - INFO - Generating test-mass acceleration noise
# 2025-07-16 11:41:11,002 - INFO - Generating ranging noise
# 2025-07-16 11:41:11,002 - INFO - Generating OMS noise
# 2025-07-16 11:41:16,102 - INFO - Generating DWS measurement noise
# 2025-07-16 11:41:16,103 - INFO - Generating MOSA longitudinal jitters
# 2025-07-16 11:41:16,103 - INFO - Generating spacecraft angular jitters
# 2025-07-16 11:41:16,103 - INFO - Generating MOSA angular jitters
# 2025-07-16 11:41:16,103 - INFO - Computing MOSA total angular jitters
# 2025-07-16 11:41:16,104 - INFO - Computing tilt-to-length couplings
# 2025-07-16 11:41:16,572 - INFO - Simulating local beams
# 2025-07-16 11:41:16,572 - INFO - Generating laser noise for laser 12
# 2025-07-16 11:41:19,796 - INFO - Propagating local beams to distant MOSAs
# 2025-07-16 11:41:58,646 - INFO - Propagating local beams to adjacent MOSAs
# 2025-07-16 11:41:58,673 - INFO - Propagating local beams to inter-spacecraft interferometers
# 2025-07-16 11:41:58,674 - INFO - Propagating distant beams to inter-spacecraft interferometers
# 2025-07-16 11:41:58,674 - INFO - Computing inter-spacecraft beatnotes on TPS
# 2025-07-16 11:41:58,862 - INFO - Computing inter-spacecraft DWS measurements on TPS
# 2025-07-16 11:41:58,863 - INFO - Computing measured pseudo-ranges on TPS
# 2025-07-16 11:41:58,894 - INFO - Propagating local beams to test-mass interferometers
# 2025-07-16 11:41:59,130 - INFO - Propagating adjacent beams to test-mass interferometers
# 2025-07-16 11:41:59,130 - INFO - Computing test-mass beatnotes on TPS
# 2025-07-16 11:41:59,304 - INFO - Propagating local beams to reference interferometers
# 2025-07-16 11:41:59,304 - INFO - Propagating adjacent beams to reference interferometers
# 2025-07-16 11:41:59,304 - INFO - Computing reference beatnotes on TPS
# 2025-07-16 11:41:59,468 - INFO - Inverting SCET with respect to TPS
# 2025-07-16 11:41:59,503 - INFO - Sampling inter-spacecraft beatnotes to SCET grid
# 2025-07-16 11:41:59,866 - INFO - Sampling measured pseudo-ranges to SCET grid
# 2025-07-16 11:41:59,902 - INFO - Sampling test-mass beatnotes to SCET grid
# 2025-07-16 11:42:00,153 - INFO - Sampling reference beatnotes to SCET grid
# 2025-07-16 11:42:00,405 - INFO - Applying electronic delays
# 2025-07-16 11:42:00,406 - INFO - Filtering beatnotes
# 2025-07-16 11:42:05,293 - INFO - Downsampling beatnotes
# 2025-07-16 11:42:05,293 - INFO - Computing total beatnote frequencies
# 2025-07-16 11:42:05,372 - INFO - Simulation complete
# 2025-07-16 11:42:05,396 - INFO - Writing simulation to 'static_3_day_simulation.h5'
# 2025-07-16 11:42:06,730 - INFO - Closing measurement file 'static_3_day_simulation.h5'

# %%
data_3_day_sim = Data.from_instrument(instr_3_days_static)
# Out:
# 2025-07-16 11:42:30,043 - INFO - Loading instrument object '<lisainstrument.instrument.Instrument object at 0x14a7bd910>'
# 2025-07-16 11:42:30,044 - WARNING - You are using LISA Instrument in a version that might not be fully supported
# 2025-07-16 11:42:30,045 - INFO - Initializing data object
# 2025-07-16 11:42:30,045 - INFO - Computing delay derivatives

# %% [markdown]
# # Define the overall masking function
#
# The masking function will take in a dictionary of gating functions

# %%
# Generate the mask with sampling interval 0.25 seconds

# Define the gap function 

# Construct gap class

sim_t = np.arange(0, simlen_multi_gap * dt, dt)

gap_definitions = {
    "planned": {
        "Instrumental Maintainance": {"rate_per_year": 5 * 260, "duration_hr": 0.0001*3.3}
    },
    "unplanned": {
        "Instrument breaks": {"rate_per_year": 3, "duration_hr": 60},
    }
}

# Initialise class with rates, and sampling properties.
generator_gap_3_day = GapMaskGenerator(
    sim_t,
    dt,
    gap_definitions,
    treat_as_nan=True,
    planseed=11_07_1993,
    unplanseed=16_12_1997
)

# Generate the mask full of gaps
full_mask_3_day = generator_gap_3_day.generate_mask(include_unplanned=False, include_planned=True)
N_nans_check = np.sum(np.isnan(full_mask_3_day))

extract_summary = generator_gap_3_day.summary(mask = full_mask_3_day)
from pprint import pprint
pprint(extract_summary['mask_analysis'])
# Out:
# {'duty_cycle_percent': np.float64(99.9962),
#  'number_of_gap_segments': 10,
#  'total_gap_hours': np.float64(0.0),
#  'total_gap_samples': 40}

# %%
plt.plot(full_mask_3_day)

# %%
# Let's compute the true number of nans in the eta variables
N_nans_multiple_gaps = np.sum(np.isnan(full_mask_3_day))

data_w_multi_gaps = nanify_telemetry_variables(data_3_day_sim, full_mask_3_day)
etas_w_multi_gaps = compute_etas(
    data_w_multi_gaps, order=order, unit="frequency"
)

LTT = data_w_multi_gaps.delays['d_12'][1000:][0]  # Take the mean LTT
delay_integer_fraction = LTT / dt  # Here we take the mean LTT. "samples"
eta_mask = mask_eta(full_mask_3_day, delay=delay_integer_fraction, order=order)

print("")
print("Doing things using pytdi")
N_nans_in_eta_w_multi_gaps_pytdi = np.sum(np.isnan(etas_w_multi_gaps["eta_12"]))
widening_gap_eta_pytdi = N_nans_in_eta_w_multi_gaps_pytdi - N_nans_multiple_gaps
print("Number of nans in the eta variables = ", N_nans_in_eta_w_multi_gaps_pytdi)
print("Overall widening of gap in eta variables = ", widening_gap_eta_pytdi)
print("")
print("Now doing things carefully but using theory")

N_nans_in_eta_w_multi_gaps_theory = np.sum(np.isnan(eta_mask))
widening_gap_eta_theory = N_nans_in_eta_w_multi_gaps_theory - N_nans_multiple_gaps
print("Number of nans in the eta variables = ", N_nans_in_eta_w_multi_gaps_theory)
print("Overall widening of gap in eta variables = ", widening_gap_eta_theory)

# Can I try to approximate this result?
print("")
print("Now using our quick approximation formula")
approx_nans_in_eta = approx_total_nans_from_nan_blocks_eta(full_mask_3_day, delay, lagrange_order=order, delay_number=1.0)

approx_N_nans_in_eta_w_multi_gaps_theory = np.sum(np.isnan(eta_mask))
approx_widening_gap_eta_theory = approx_N_nans_in_eta_w_multi_gaps_theory - N_nans_multiple_gaps
print("Approx number of nans in the eta variables = ", approx_N_nans_in_eta_w_multi_gaps_theory)
print("Overall widening of gap in eta variables = ", approx_widening_gap_eta_theory)
# Out:
# 2025-07-16 14:19:06,124 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# 2025-07-16 14:19:06,125 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424e60>'
# /opt/miniconda3/envs/pytdi_env/lib/python3.12/site-packages/pytdi/dsp.py:113: RuntimeWarning: invalid value encountered in cast
#   shift_ints = shift_ints.astype(int)
# 2025-07-16 14:19:07,218 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 14:19:07,220 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a41a840>'
# 2025-07-16 14:19:08,316 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 14:19:08,317 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426840>'
# 2025-07-16 14:19:09,408 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 14:19:09,410 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a424920>'
# 2025-07-16 14:19:10,133 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 14:19:10,135 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a426b40>'
# 2025-07-16 14:19:10,865 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# 2025-07-16 14:19:10,866 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a4180b0>'
# Doing things using pytdi
# Number of nans in the eta variables =  530
# Overall widening of gap in eta variables =  490
#
# Now doing things carefully but using theory
# Number of nans in the eta variables =  530
# Overall widening of gap in eta variables =  490
#
# Now using our quick approximation formula
# Approx number of nans in the eta variables =  530
# Overall widening of gap in eta variables =  490

# %% [markdown]
# <!-- # Try to do the same thing but with TDI X variables for both generations -->

# %%
# Compute TDI variables for generation 1 and generation 2
order = 45
TDI_X = []
for gen in range(1, 3):
    result = compute_factorized_michelson(
    data_w_multi_gaps, etas = etas_w_multi_gaps, rot=0, order=order, generation=gen
    )
    TDI_X.append(result)
# Out:
# 2025-07-16 14:19:16,810 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 14:19:16,811 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x15a3868a0>'
# 2025-07-16 14:19:16,813 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x15a3868a0>'
# 2025-07-16 14:19:17,204 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-07-16 14:19:17,204 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x159814b90>'
# 2025-07-16 14:19:17,206 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x159814b90>'
# 2025-07-16 14:19:17,574 - INFO - Initializing combination with components '{'x_arm_1': [(-1, []), (1, ['D_13', 'D_31'])], 'x_arm_2': [(1, []), (-1, ['D_12', 'D_21'])]}'
# 2025-07-16 14:19:17,575 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fb6b800>'
# 2025-07-16 14:19:17,721 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fb6b800>'
# 2025-07-16 14:19:18,473 - INFO - Initializing combination with components '{'eta_12': [(1, [])], 'eta_21': [(1, ['D_12'])]}'
# 2025-07-16 14:19:18,474 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a7d8bf0>'
# 2025-07-16 14:19:18,475 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a7d8bf0>'
# 2025-07-16 14:19:18,880 - INFO - Initializing combination with components '{'eta_13': [(1, [])], 'eta_31': [(1, ['D_13'])]}'
# 2025-07-16 14:19:18,880 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a7d9dc0>'
# 2025-07-16 14:19:18,881 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a7d9dc0>'
# 2025-07-16 14:19:19,262 - INFO - Initializing combination with components '{'arm_a': [(1, [])], 'arm_b': [(1, ['D_12', 'D_21'])]}'
# 2025-07-16 14:19:19,262 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a7d9dc0>'
# 2025-07-16 14:19:19,354 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a7d9dc0>'
# 2025-07-16 14:19:19,752 - INFO - Initializing combination with components '{'arm_a': [(1, ['D_13', 'D_31'])], 'arm_b': [(1, [])]}'
# 2025-07-16 14:19:19,752 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14a7d8bf0>'
# 2025-07-16 14:19:19,826 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14a7d8bf0>'
# 2025-07-16 14:19:20,227 - INFO - Initializing combination with components '{'roundtrip_a': [(-1, []), (1, ['D_13', 'D_31', 'D_12', 'D_21'])], 'roundtrip_b': [(1, []), (-1, ['D_12', 'D_21', 'D_13', 'D_31'])]}'
# 2025-07-16 14:19:20,227 - INFO - Building combination '<pytdi.core.LISATDICombination object at 0x14fc9c980>'
# 2025-07-16 14:19:20,655 - INFO - Evaluate combination '<pytdi.core.LISATDICombination object at 0x14fc9c980>'

# %%
N_nans_multiple_gaps = np.sum(np.isnan(full_mask_3_day))

X2_mask = mask_TDI_X(full_mask_3_day, delay_integer_fraction, order=order, generation=2)

check_N_nans_in_X2_theory = approx_total_nans_from_nan_blocks_X(full_mask_3_day, delay_integer_fraction, order=order, generation=2)

N_nans_using_X2_mask = np.sum(np.isnan(X2_mask))

N_nans_using_pytdi_X2 = np.sum(np.isnan(TDI_X[1]))

print("widening for TDI2 using pytdi ", N_nans_using_pytdi_X2 - N_nans_multiple_gaps)
print("widening for TDI2 using mask ", N_nans_using_X2_mask - N_nans_multiple_gaps)
print("widening for TDI2 using formulas ", check_N_nans_in_X2_theory - N_nans_multiple_gaps)
# Out:
# widening for TDI2 using pytdi  3500
# widening for TDI2 using mask  3500
# widening for TDI2 using formulas  3500

# %%
print("Using pytdi")
N_nans_in_X1_w_multi_gaps_pytdi = np.sum(np.isnan(TDI_X[0]))
N_nans_in_X2_w_multi_gaps_pytdi = np.sum(np.isnan(TDI_X[1]))

widening_gap_X1_pytdi = N_nans_in_X1_w_multi_gaps_pytdi - N_nans_multiple_gaps
widening_gap_X2_pytdi = N_nans_in_X2_w_multi_gaps_pytdi - N_nans_multiple_gaps
print("pytdi: Number of nans in X1 variables = ", N_nans_in_X1_w_multi_gaps_pytdi)
print("pytdi: Widening of gap in X1 variables = ", widening_gap_X1_pytdi)
print("pytdi: Number of nans in X2 variables = ", N_nans_in_X2_w_multi_gaps_pytdi)
print("pytdi: Widening of gap in X2 variables = ", widening_gap_X2_pytdi)

print("")
print("Now doing things carefully but using theory")
print("")

# Compute the masking function for X1 and X2 variables using formulas
X1_mask = mask_TDI_X(full_mask_3_day, delay, order=order, generation=1)
X2_mask = mask_TDI_X(full_mask_3_day, delay, order=order, generation=2)

N_nans_in_X1_w_multi_gaps_theory = np.sum(np.isnan(X1_mask))
N_nans_in_X2_w_multi_gaps_theory = np.sum(np.isnan(X2_mask))
widening_gap_X1_theory = N_nans_in_X1_w_multi_gaps_theory - N_nans_multiple_gaps
widening_gap_X2_theory = N_nans_in_X2_w_multi_gaps_theory - N_nans_multiple_gaps
print("Theory: Number of nans in X1 variables = ", N_nans_in_X1_w_multi_gaps_theory)
print("Theory: Widening of gap in X1 variables = ", widening_gap_X1_theory)
print("Theory: Number of nans in X2 variables = ", N_nans_in_X2_w_multi_gaps_theory)
print("Theory: Widening of gap in X2 variables = ", widening_gap_X2_theory)
print("")
# Can I try to approximate this result?
print("Now using our quick approximation formula")
print("")
approx_nans_in_X1 = approx_total_nans_from_nan_blocks_X(full_mask_3_day, delay_integer_fraction, order=order, generation=1)
approx_nans_in_X2 = approx_total_nans_from_nan_blocks_X(full_mask_3_day, delay_integer_fraction, order=order, generation=2)

approx_N_nans_in_X1_w_multi_gaps_theory = np.sum(np.isnan(X1_mask))
approx_N_nans_in_X2_w_multi_gaps_theory = np.sum(np.isnan(X2_mask))
approx_widening_gap_X1_theory = approx_N_nans_in_X1_w_multi_gaps_theory - N_nans_multiple_gaps
approx_widening_gap_X2_theory = approx_N_nans_in_X2_w_multi_gaps_theory - N_nans_multiple_gaps
print("Approx: Number of nans in X1 variables = ", approx_N_nans_in_X1_w_multi_gaps_theory)
print("Approx:  Widening of gap in X1 variables = ", approx_widening_gap_X1_theory)
print("Approx: Number of nans in X2 variables = ", approx_N_nans_in_X2_w_multi_gaps_theory)
print("Approx:  Widening of gap in X2 variables = ", approx_widening_gap_X2_theory)
# Out:
# Using pytdi
# pytdi: Number of nans in X1 variables =  1980
# pytdi: Widening of gap in X1 variables =  1940
# pytdi: Number of nans in X2 variables =  3540
# pytdi: Widening of gap in X2 variables =  3500
#
# Now doing things carefully but using theory
#
# Theory: Number of nans in X1 variables =  1980
# Theory: Widening of gap in X1 variables =  1940
# Theory: Number of nans in X2 variables =  3540
# Theory: Widening of gap in X2 variables =  3500
#
# Now using our quick approximation formula
#
# Approx: Number of nans in X1 variables =  1980
# Approx:  Widening of gap in X1 variables =  1940
# Approx: Number of nans in X2 variables =  3540
# Approx:  Widening of gap in X2 variables =  3500
